# %% [markdown]
# # Pandas Data Cleaning - Cumulative Lab
#
# ## Introduction
# In this lab, we'll make use of everything we've learned about pandas, data cleaning, and exploratory data analysis. In order to complete this lab, you'll have to import, clean, combine, reshape, and visualize data to answer questions provided, as well as your own questions!
#
# ## Objectives
# You will be able to:
# - Practice opening and inspecting the contents of CSVs using pandas dataframes
# - Practice identifying and handling missing values
# - Practice identifying and handling invalid values
# - Practice cleaning text data by removing whitespace and fixing typos
# - Practice joining multiple dataframes

# %% [markdown]
# ## Your Task: Clean the Superheroes Dataset with Pandas
#
# ![LEGO superheroes](images/lego_superheroes.jpg)
#
# Photo by <a href="https://unsplash.com/@yuliamatvienko?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Yulia Matvienko</a> on <a href="/s/photos/superhero?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Data Understanding
# In this lab, we'll work with a version of the comprehensive Superheroes Dataset, which can be found on [Kaggle](https://www.kaggle.com/claudiodavi/superhero-set/data) and was originally scraped from [SuperHeroDb](https://www.superherodb.com/). We have modified the structure and contents of the dataset somewhat for the purposes of this lab.  Note that this data was collected in June 2017, so it may not reflect the most up-to-date superhero lore.
#
# The data is contained in two separate CSV files:
#
# 1. `heroes_information.csv`: each record represents a superhero, with attributes of that superhero (e.g. eye color). Height is measured in centimeters, and weight is measured in pounds.
# 2. `super_hero_powers.csv`: each record represents a superpower, then has True/False values representing whether each superhero has that power
#
# ### Business Understanding
#
# The business questions you have been provided are:
#
# 1. What is the distribution of superheroes by publisher?
# 2. What is the relationship between height and number of superpowers? And does this differ based on gender?
# 3. What are the 5 most common superpowers in Marvel Comics vs. DC Comics?
#
# This lab also simulates something you are likely to encounter at some point or another in your career in data science: someone has given you access to a dataset, as well as a few questions, and has told you to "find something interesting".
#
# So, in addition to completing the basic data cleaning tasks and the aggregation and reshaping tasks needed to answer the provided questions, you will also need to formulate a question of your own and perform any additional cleaning/aggregation/reshaping that is needed to answer it.

# %% [markdown]
# ### Requirements
#
# #### 1. Load the Data with Pandas
#
# Create a dataframes `heroes_df` and `powers_df` that represent the two CSV files. Use pandas methods to inspect the shape and other attributes of these dataframes.
#
# #### 2. Perform Data Cleaning Required to Answer First Question
#
# The first question is: *What is the distribution of superheroes by publisher?*
#
# In order to answer this question, you will need to:
#
# * Identify and handle missing values
# * Identify and handle text data requiring cleaning
#
# #### 3. Perform Data Aggregation and Cleaning Required to Answer Second Question
#
# The second question is: *What is the relationship between height and number of superpowers? And does this differ based on gender?*
#
# In order to answer this question, you will need to:
#
# * Join the dataframes together
# * Identify and handle invalid values
#
# #### 4. Perform Data Aggregation Required to Answer Third Question
#
# The third question is: *What are the 5 most common superpowers in Marvel Comics vs. DC Comics?*
#
# This should not require any additional data cleaning or joining of tables, but it will require some additional aggregation.
#
# #### 5. Formulate and Answer Your Own Question
#
# This part is fairly open-ended. Think of a question that can be answered with the available data, and perform any cleaning or aggregation required to answer that question.

# %% [markdown]
# ## 1. Load the Data with Pandas
#
# In the cell below, we:
#
# * Import and alias `pandas` as `pd`
# * Import and alias `numpy` as `np`
# * Import and alias `seaborn` as `sns`
# * Import and alias `matplotlib.pyplot` as `plt`
# * Set Matplotlib visualizations to display inline in the notebook

# %%
# !git remote -v

# %%
# Run this cell without changes

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Superheroes
#
# In the cell below, load `heroes_information.csv` as `heroes_df`:

# %% [markdown]
# It looks like that CSV came with an index column, resulting in an extra column called `Unnamed: 0`. We don't need that column, so write code to get rid of it below.
#
# There are two ways to do this:
#
# 1. Re-load with `read_csv`, and specify the parameter `index_col=0`
# 2. Drop the column `Unnamed: 0` with `axis=1`

# %%
heroes_df = pd.read_csv('heroes_information.csv',index_col=0)
heroes_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %% [markdown]
# The following code checks that the dataframe was loaded correctly.

# %%
# Run this cell without changes

# There should be 734 rows
assert heroes_df.shape[0] == 734

# There should be 10 columns. If this fails, make sure you got rid of
# the extra index column
assert heroes_df.shape[1] == 10

# These should be the columns
assert list(heroes_df.columns) == ['name', 'Gender', 'Eye color', 'Race',
 'Hair color', 'Height', 'Publisher', 'Skin color', 'Alignment', 'Weight']

# %% [markdown]
# Now you want to get familiar with the data.  This step includes:
#
# * Understanding the dimensionality of your dataset
# * Investigating what type of data it contains, and the data types used to store it
# * Discovering how missing values are encoded, and how many there are
# * Getting a feel for what information it does and doesn't contain
#
# In the cell below, inspect the overall shape of the dataframe:

# %%
# Your code here
heroes_df.shape
# Out:
# (734, 10)

# %% [markdown]
# Now let's look at the info printout:

# %%
# Run this cell without changes
heroes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 734 entries, 0 to 733
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        734 non-null    object
#  1   Gender      734 non-null    object
#  2   Eye color   734 non-null    object
#  3   Race        734 non-null    object
#  4   Hair color  734 non-null    object
#  5   Height      734 non-null    float64
#  6   Publisher   719 non-null    object
#  7   Skin color  734 non-null    object
#  8   Alignment   734 non-null    object
#  9   Weight      732 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 63.1+ KB

# %% [markdown]
# In the cell below, interpret that information. Do the data types line up with what we expect? Are there any missing values?

# %%
# Replace None with appropriate text
"""
None
"""
# Out:
# '\nNone\n'

# %% [markdown]
# ### Superpowers
#
# Now, repeat the same process with `super_hero_powers.csv`. Name the dataframe `powers_df`. This time, make sure you use `index_col=0` when opening the CSV because the index contains important information.

# %%
# Your code here (create more cells as needed)
powers_df = pd.read_csv('super_hero_powers.csv', index_col=0)
powers_df.head()
# Out:
#                        3-D Man  A-Bomb  Abe Sapien  Abin Sur  Abomination  \
# Agility                   True   False        True     False        False
# Accelerated Healing      False    True        True     False         True
# Lantern Power Ring       False   False       False      True        False
# Dimensional Awareness    False   False       False     False        False
# Cold Resistance          False   False        True     False        False
#
#                        Abraxas  Absorbing Man  Adam Monroe  Adam Strange  \
# Agility                  False          False        False         False
# Accelerated Healing      False          False         True         False
# Lantern Power Ring       False          False        False         False
# Dimensional Awareness     True          False        False         False
# Cold Resistance          False           True        False         False
#
#                        Agent Bob  ...  Wonder Man  Wonder Woman   X-23  X-Man  \
# Agility                    False  ...       False         False   True  False
# Accelerated Healing        False  ...       False          True   True  False
# Lantern Power Ring         False  ...       False         False  False  False
# Dimensional Awareness      False  ...       False         False  False  False
# Cold Resistance            False  ...       False         False  False  False
#
#                        Yellowjacket  Yellowjacket II   Ymir   Yoda  Zatanna  \
# Agility                       False            False  False   True    False
# Accelerated Healing           False            False  False  False    False
# Lantern Power Ring            False            False  False  False    False
# Dimensional Awareness         False            False  False  False    False
# Cold Resistance               False            False   True  False    False
#
#                         Zoom
# Agility                False
# Accelerated Healing    False
# Lantern Power Ring     False
# Dimensional Awareness  False
# Cold Resistance        False
#
# [5 rows x 667 columns]

# %% [markdown]
# The following code will check if it was loaded correctly:

# %%
# Run this cell without changes

# There should be 167 rows, 667 columns
assert powers_df.shape == (167, 667)

# The first column should be '3-D Man'
assert powers_df.columns[0] == '3-D Man'

# The last column should be 'Zoom'
assert powers_df.columns[-1] == 'Zoom'

# The first index should be 'Agility'
assert powers_df.index[0] == 'Agility'

# The last index should be 'Omniscient'
assert powers_df.index[-1] == 'Omniscient'

# %% [markdown]
# ## 2. Perform Data Cleaning Required to Answer First Question
#
# Recall that the first question is: *What is the distribution of superheroes by publisher?*
#
# To answer this question, we will only need to use `heroes_df`, which contains the `Publisher` column.
#
# ### Identifying and Handling Missing Values
#
# As you likely noted above, the `Publisher` column is missing some values. Let's take a look at some samples with and without missing publisher values:

# %%
# Run this cell without changes
has_publisher_sample = heroes_df[heroes_df["Publisher"].notna()].sample(5, random_state=1)
has_publisher_sample
# Out:
#            name  Gender Eye color   Race        Hair color  Height  \
# 60      Banshee    Male     green  Human  Strawberry Blond   183.0
# 61       Bantam    Male     brown      -             Black   165.0
# 219  DL Hawkins    Male         -      -                 -   -99.0
# 650       Synch    Male     brown      -             Black   180.0
# 8      Agent 13  Female      blue      -             Blond   173.0
#
#          Publisher Skin color Alignment  Weight
# 60   Marvel Comics          -      good    77.0
# 61   Marvel Comics          -      good    54.0
# 219   NBC - Heroes          -      good   -99.0
# 650  Marvel Comics          -      good    74.0
# 8    Marvel Comics          -      good    61.0

# %%
# Run this cell without changes
missing_publisher_sample = heroes_df[heroes_df["Publisher"].isna()].sample(5, random_state=1)
missing_publisher_sample
# Out:
#                  name  Gender Eye color    Race Hair color  Height Publisher  \
# 175      Chuck Norris    Male         -       -          -   178.0       NaN
# 286          Godzilla       -         -   Kaiju          -   108.0       NaN
# 263      Flash Gordon    Male         -       -          -   -99.0       NaN
# 138        Brundlefly    Male         -  Mutant          -   193.0       NaN
# 381  Katniss Everdeen  Female         -   Human          -   -99.0       NaN
#
#     Skin color Alignment  Weight
# 175          -      good   -99.0
# 286       grey       bad     NaN
# 263          -      good   -99.0
# 138          -         -   -99.0
# 381          -      good   -99.0

# %% [markdown]
# What do we want to do about these missing values?
#
# Recall that there are two general strategies for dealing with missing values:
#
# 1. Fill in missing values (either using another value from the column, e.g. the mean or mode, or using some other value like "Unknown")
# 2. Drop rows with missing values
#
# Write your answer below, and explain how it relates to the information we have:

# %%
# Replace None with appropriate text
"""
None
"""
# Out:
# '\nNone\n'

# %% [markdown]
# Now, implement your chosen strategy using code. (You can also check the solution branch for the answer to the question above if you're really not sure.)

# %%
# Your code here
heroes_df.dropna(subset=["Publisher"], inplace=True)

# %% [markdown]
# Now there should be no missing values in the publisher column:

# %%
# Run this cell without changes
assert heroes_df["Publisher"].isna().sum() == 0

# %% [markdown]
# ### Identifying and Handling Text Data Requiring Cleaning
#
# The overall field of natural language processing (NLP) is quite broad, and we're not going to get into any advanced text processing, but it's useful to be able to clean up minor issues in text data.
#
# Let's take a look at the counts of heroes grouped by publisher:

# %%
# Run this cell without changes
heroes_df["Publisher"].value_counts()
# Out:
# Marvel Comics        379
# DC Comics            212
# NBC - Heroes          19
# Dark Horse Comics     18
# Image Comics          14
# George Lucas          14
# Marvel                 9
# Star Trek              6
# HarperCollins          6
# Team Epic TV           5
# SyFy                   5
# Icon Comics            4
# Shueisha               4
# IDW Publishing         4
# ABC Studios            4
#  DC Comics             3
# Wildstorm              3
# Sony Pictures          2
# Microsoft              1
# Rebellion              1
# South Park             1
# J. R. R. Tolkien       1
# Universal Studios      1
# Titan Books            1
# Hanna-Barbera          1
# J. K. Rowling          1
# Name: Publisher, dtype: int64

# %% [markdown]
# There are two cases where we appear to have data entry issues, and publishers that should be encoded the same have not been. In other words, there are four categories present that really should be counted as two categories (and you do not need specific comic book knowledge to be able to identify them).
#
# Identify those two cases below:

# %%
# Replace None with appropriate text
"""
None
"""
# Out:
# '\nNone\n'

# %% [markdown]
# Now, write some code to handle these cases. If you're not sure where to start, look at the pandas documentation for [replacing values](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.replace.html) and [stripping off whitespace](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.strip.html).

# %%
# Your code here

heroes_df["Publisher"] = heroes_df["Publisher"].replace("Marvel", "Marvel Comics")
heroes_df["Publisher"] = heroes_df["Publisher"].str.strip()

# %% [markdown]
# Check your work below:

# %%
# Run this cell without changes
heroes_df["Publisher"].value_counts()
# Out:
# Marvel Comics        388
# DC Comics            215
# NBC - Heroes          19
# Dark Horse Comics     18
# George Lucas          14
# Image Comics          14
# Star Trek              6
# HarperCollins          6
# Team Epic TV           5
# SyFy                   5
# ABC Studios            4
# Shueisha               4
# Icon Comics            4
# IDW Publishing         4
# Wildstorm              3
# Sony Pictures          2
# Microsoft              1
# Universal Studios      1
# J. R. R. Tolkien       1
# Rebellion              1
# Titan Books            1
# Hanna-Barbera          1
# South Park             1
# J. K. Rowling          1
# Name: Publisher, dtype: int64

# %% [markdown]
# ### Answering the Question
#
# Now we should be able to answer *What is the distribution of superheroes by publisher?*
#
# If your data cleaning was done correctly, this code should work without any further changes:

# %%
# Run this cell without changes

# Set up plots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 5))

# Create variables for easier reuse
value_counts = heroes_df["Publisher"].value_counts()
top_5_counts = value_counts.iloc[:5]

# Plot data
ax1.bar(value_counts.index, value_counts.values)
ax2.bar(top_5_counts.index, top_5_counts.values)

# Customize appearance
ax1.tick_params(axis="x", labelrotation=90)
ax2.tick_params(axis="x", labelrotation=45)
ax1.set_ylabel("Count of Superheroes")
ax2.set_ylabel("Count of Superheroes")
ax1.set_title("Distribution of Superheroes by Publisher")
ax2.set_title("Top 5 Publishers by Count of Superheroes");

# %% [markdown]
# ## 3. Perform Data Aggregation and Cleaning Required to Answer Second Question
#
# Recall that the second question is: *What is the relationship between height and number of superpowers? And does this differ based on gender?*
#
# Unlike the previous question, we won't be able to answer this with just `heroes_df`, since information about height is contained in `heroes_df`, while information about superpowers is contained in `powers_df`.
#
# ### Joining the Dataframes Together
#
# First, identify the shared key between `heroes_df` and `powers_df`. (Shared key meaning, the values you want to join on.) Let's look at them again:

# %%
# Run this cell without changes
heroes_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight
# 0     203.0      Marvel Comics          -      good   441.0
# 1     191.0  Dark Horse Comics       blue      good    65.0
# 2     185.0          DC Comics        red      good    90.0
# 3     203.0      Marvel Comics          -       bad   441.0
# 4     -99.0      Marvel Comics          -       bad   -99.0
# ..      ...                ...        ...       ...     ...
# 729   165.0      Marvel Comics          -      good    52.0
# 730   304.8      Marvel Comics      white      good   -99.0
# 731    66.0       George Lucas      green      good    17.0
# 732   170.0          DC Comics          -      good    57.0
# 733   185.0          DC Comics          -       bad    81.0
#
# [719 rows x 10 columns]

# %%
# Run this cell without changes
powers_df
# Out:
#                        3-D Man  A-Bomb  Abe Sapien  Abin Sur  Abomination  \
# Agility                   True   False        True     False        False
# Accelerated Healing      False    True        True     False         True
# Lantern Power Ring       False   False       False      True        False
# Dimensional Awareness    False   False       False     False        False
# Cold Resistance          False   False        True     False        False
# ...                        ...     ...         ...       ...          ...
# Phoenix Force            False   False       False     False        False
# Molecular Dissipation    False   False       False     False        False
# Vision - Cryo            False   False       False     False        False
# Omnipresent              False   False       False     False        False
# Omniscient               False   False       False     False        False
#
#                        Abraxas  Absorbing Man  Adam Monroe  Adam Strange  \
# Agility                  False          False        False         False
# Accelerated Healing      False          False         True         False
# Lantern Power Ring       False          False        False         False
# Dimensional Awareness     True          False        False         False
# Cold Resistance          False           True        False         False
# ...                        ...            ...          ...           ...
# Phoenix Force            False          False        False         False
# Molecular Dissipation    False          False        False         False
# Vision - Cryo            False          False        False         False
# Omnipresent              False          False        False         False
# Omniscient               False          False        False         False
#
#                        Agent Bob  ...  Wonder Man  Wonder Woman   X-23  X-Man  \
# Agility                    False  ...       False         False   True  False
# Accelerated Healing        False  ...       False          True   True  False
# Lantern Power Ring         False  ...       False         False  False  False
# Dimensional Awareness      False  ...       False         False  False  False
# Cold Resistance            False  ...       False         False  False  False
# ...                          ...  ...         ...           ...    ...    ...
# Phoenix Force              False  ...       False         False  False  False
# Molecular Dissipation      False  ...       False         False  False  False
# Vision - Cryo              False  ...       False         False  False  False
# Omnipresent                False  ...       False         False  False  False
# Omniscient                 False  ...       False         False  False  False
#
#                        Yellowjacket  Yellowjacket II   Ymir   Yoda  Zatanna  \
# Agility                       False            False  False   True    False
# Accelerated Healing           False            False  False  False    False
# Lantern Power Ring            False            False  False  False    False
# Dimensional Awareness         False            False  False  False    False
# Cold Resistance               False            False   True  False    False
# ...                             ...              ...    ...    ...      ...
# Phoenix Force                 False            False  False  False    False
# Molecular Dissipation         False            False  False  False    False
# Vision - Cryo                 False            False  False  False    False
# Omnipresent                   False            False  False  False    False
# Omniscient                    False            False  False  False    False
#
#                         Zoom
# Agility                False
# Accelerated Healing    False
# Lantern Power Ring     False
# Dimensional Awareness  False
# Cold Resistance        False
# ...                      ...
# Phoenix Force          False
# Molecular Dissipation  False
# Vision - Cryo          False
# Omnipresent            False
# Omniscient             False
#
# [167 rows x 667 columns]

# %% [markdown]
# In the cell below, identify the shared key, and your strategy for joining the data (e.g. what will one record represent after you join, will you do a left/right/inner/outer join):

# %%
# Replace None with appropriate text
"""
None
"""
# Out:
# '\nNone\n'

# %% [markdown]
# In the cell below, create a new dataframe called `heroes_and_powers_df` that contains the joined data. You can look at the above answer in the solution branch if you're not sure where to start.
#
# ***Hint:*** Note that the `.join` method requires that the two dataframes share an index ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.join.html)) whereas the `.merge` method can join using any columns ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html)). It is up to you which one you want to use.

# %%
# Your code here (create more cells as needed)
powers_df_transposed = powers_df.T
powers_df_transposed
# Out:
#                  Agility  Accelerated Healing  Lantern Power Ring  \
# 3-D Man             True                False               False
# A-Bomb             False                 True               False
# Abe Sapien          True                 True               False
# Abin Sur           False                False                True
# Abomination        False                 True               False
# ...                  ...                  ...                 ...
# Yellowjacket II    False                False               False
# Ymir               False                False               False
# Yoda                True                False               False
# Zatanna            False                False               False
# Zoom               False                False               False
#
#                  Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 3-D Man                          False            False       False    False
# A-Bomb                           False            False        True    False
# Abe Sapien                       False             True        True    False
# Abin Sur                         False            False       False    False
# Abomination                      False            False       False    False
# ...                                ...              ...         ...      ...
# Yellowjacket II                  False            False       False    False
# Ymir                             False             True        True    False
# Yoda                             False            False       False     True
# Zatanna                          False            False       False    False
# Zoom                             False            False       False    False
#
#                  Energy Absorption  Flight  Danger Sense  ...  Web Creation  \
# 3-D Man                      False   False         False  ...         False
# A-Bomb                       False   False         False  ...         False
# Abe Sapien                   False   False         False  ...         False
# Abin Sur                     False   False         False  ...         False
# Abomination                  False   False         False  ...         False
# ...                            ...     ...           ...  ...           ...
# Yellowjacket II              False    True         False  ...         False
# Ymir                         False   False         False  ...         False
# Yoda                         False   False          True  ...         False
# Zatanna                      False   False         False  ...         False
# Zoom                         False   False         False  ...         False
#
#                  Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 3-D Man                    False       False             False        False
# A-Bomb                     False       False             False        False
# Abe Sapien                 False       False             False        False
# Abin Sur                   False       False             False        False
# Abomination                False       False             False        False
# ...                          ...         ...               ...          ...
# Yellowjacket II            False       False             False        False
# Ymir                       False       False             False        False
# Yoda                       False       False             False        False
# Zatanna                    False       False             False        False
# Zoom                       False       False             False        False
#
#                  Phoenix Force  Molecular Dissipation  Vision - Cryo  \
# 3-D Man                  False                  False          False
# A-Bomb                   False                  False          False
# Abe Sapien               False                  False          False
# Abin Sur                 False                  False          False
# Abomination              False                  False          False
# ...                        ...                    ...            ...
# Yellowjacket II          False                  False          False
# Ymir                     False                  False          False
# Yoda                     False                  False          False
# Zatanna                  False                  False          False
# Zoom                     False                  False          False
#
#                  Omnipresent  Omniscient
# 3-D Man                False       False
# A-Bomb                 False       False
# Abe Sapien             False       False
# Abin Sur               False       False
# Abomination            False       False
# ...                      ...         ...
# Yellowjacket II        False       False
# Ymir                   False       False
# Yoda                   False       False
# Zatanna                False       False
# Zoom                   False       False
#
# [667 rows x 167 columns]

# %%
powers_df_transposed.index.name = "name"
powers_df_transposed.reset_index(inplace=True)
powers_df_transposed
# Out:
#                 name  Agility  Accelerated Healing  Lantern Power Ring  \
# 0            3-D Man     True                False               False
# 1             A-Bomb    False                 True               False
# 2         Abe Sapien     True                 True               False
# 3           Abin Sur    False                False                True
# 4        Abomination    False                 True               False
# ..               ...      ...                  ...                 ...
# 662  Yellowjacket II    False                False               False
# 663             Ymir    False                False               False
# 664             Yoda     True                False               False
# 665          Zatanna    False                False               False
# 666             Zoom    False                False               False
#
#      Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                    False            False       False    False
# 1                    False            False        True    False
# 2                    False             True        True    False
# 3                    False            False       False    False
# 4                    False            False       False    False
# ..                     ...              ...         ...      ...
# 662                  False            False       False    False
# 663                  False             True        True    False
# 664                  False            False       False     True
# 665                  False            False       False    False
# 666                  False            False       False    False
#
#      Energy Absorption  Flight  ...  Web Creation  Reality Warping  \
# 0                False   False  ...         False            False
# 1                False   False  ...         False            False
# 2                False   False  ...         False            False
# 3                False   False  ...         False            False
# 4                False   False  ...         False            False
# ..                 ...     ...  ...           ...              ...
# 662              False    True  ...         False            False
# 663              False   False  ...         False            False
# 664              False   False  ...         False            False
# 665              False   False  ...         False            False
# 666              False   False  ...         False            False
#
#      Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# 0         False             False        False          False
# 1         False             False        False          False
# 2         False             False        False          False
# 3         False             False        False          False
# 4         False             False        False          False
# ..          ...               ...          ...            ...
# 662       False             False        False          False
# 663       False             False        False          False
# 664       False             False        False          False
# 665       False             False        False          False
# 666       False             False        False          False
#
#      Molecular Dissipation  Vision - Cryo  Omnipresent  Omniscient
# 0                    False          False        False       False
# 1                    False          False        False       False
# 2                    False          False        False       False
# 3                    False          False        False       False
# 4                    False          False        False       False
# ..                     ...            ...          ...         ...
# 662                  False          False        False       False
# 663                  False          False        False       False
# 664                  False          False        False       False
# 665                  False          False        False       False
# 666                  False          False        False       False
#
# [667 rows x 168 columns]

# %%
heroes_and_powers_df = heroes_df.merge(powers_df_transposed, on="name", how="inner")
heroes_and_powers_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 642  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 643             Ymir    Male     white        Frost Giant           No Hair
# 644             Yoda    Male     brown     Yoda's species             White
# 645          Zatanna  Female      blue              Human             Black
# 646             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  ...  \
# 0     203.0      Marvel Comics          -      good   441.0  ...
# 1     191.0  Dark Horse Comics       blue      good    65.0  ...
# 2     185.0          DC Comics        red      good    90.0  ...
# 3     203.0      Marvel Comics          -       bad   441.0  ...
# 4     -99.0      Marvel Comics          -       bad   -99.0  ...
# ..      ...                ...        ...       ...     ...  ...
# 642   165.0      Marvel Comics          -      good    52.0  ...
# 643   304.8      Marvel Comics      white      good   -99.0  ...
# 644    66.0       George Lucas      green      good    17.0  ...
# 645   170.0          DC Comics          -      good    57.0  ...
# 646   185.0          DC Comics          -       bad    81.0  ...
#
#      Web Creation  Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0           False            False       False             False        False
# 1           False            False       False             False        False
# 2           False            False       False             False        False
# 3           False            False       False             False        False
# 4           False            False       False             False        False
# ..            ...              ...         ...               ...          ...
# 642         False            False       False             False        False
# 643         False            False       False             False        False
# 644         False            False       False             False        False
# 645         False            False       False             False        False
# 646         False            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 4            False                  False          False        False
# ..             ...                    ...            ...          ...
# 642          False                  False          False        False
# 643          False                  False          False        False
# 644          False                  False          False        False
# 645          False                  False          False        False
# 646          False                  False          False        False
#
#      Omniscient
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# 642       False
# 643       False
# 644       False
# 645       False
# 646       False
#
# [647 rows x 177 columns]

# %% [markdown]
# Run the code below to check your work:

# %%
# Run this cell without changes

# Confirms you have created a dataframe with the specified name
assert type(heroes_and_powers_df) == pd.DataFrame

# Confirms you have the right number of rows
assert heroes_and_powers_df.shape[0] == 647

# Confirms you have the necessary columns
# (If you modified the value of powers_df along the way, you might need to
# modify this test. We are checking that all of the powers are present as
# columns.)
assert [power in heroes_and_powers_df.columns for power in powers_df.index]
# (If you modified the value of heroes_df along the way, you mgith need to 
# modify this as well. We are checking that all of the attribute columns from
# heroes_df are present as columns in the joined df)
assert [attribute in heroes_and_powers_df.columns for attribute in heroes_df.columns]

# %% [markdown]
# Now that we have created a joined dataframe, we can aggregate the number of superpowers by superhero. This code is written for you:

# %%
heroes_and_powers_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 642  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 643             Ymir    Male     white        Frost Giant           No Hair
# 644             Yoda    Male     brown     Yoda's species             White
# 645          Zatanna  Female      blue              Human             Black
# 646             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  ...  \
# 0     203.0      Marvel Comics          -      good   441.0  ...
# 1     191.0  Dark Horse Comics       blue      good    65.0  ...
# 2     185.0          DC Comics        red      good    90.0  ...
# 3     203.0      Marvel Comics          -       bad   441.0  ...
# 4     -99.0      Marvel Comics          -       bad   -99.0  ...
# ..      ...                ...        ...       ...     ...  ...
# 642   165.0      Marvel Comics          -      good    52.0  ...
# 643   304.8      Marvel Comics      white      good   -99.0  ...
# 644    66.0       George Lucas      green      good    17.0  ...
# 645   170.0          DC Comics          -      good    57.0  ...
# 646   185.0          DC Comics          -       bad    81.0  ...
#
#      Web Creation  Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0           False            False       False             False        False
# 1           False            False       False             False        False
# 2           False            False       False             False        False
# 3           False            False       False             False        False
# 4           False            False       False             False        False
# ..            ...              ...         ...               ...          ...
# 642         False            False       False             False        False
# 643         False            False       False             False        False
# 644         False            False       False             False        False
# 645         False            False       False             False        False
# 646         False            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 4            False                  False          False        False
# ..             ...                    ...            ...          ...
# 642          False                  False          False        False
# 643          False                  False          False        False
# 644          False                  False          False        False
# 645          False                  False          False        False
# 646          False                  False          False        False
#
#      Omniscient
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# 642       False
# 643       False
# 644       False
# 645       False
# 646       False
#
# [647 rows x 177 columns]

# %%
# Run this cell without changes

# Note: we can use sum() with True and False values and they will
# automatically be cast to 1s and 0s
heroes_and_powers_df["Power Count"] = sum([heroes_and_powers_df[power_name] for power_name in powers_df.index])
heroes_and_powers_df

# %%
powers_df.T
# Out:
#                  Agility  Accelerated Healing  Lantern Power Ring  \
# name
# 3-D Man             True                False               False
# A-Bomb             False                 True               False
# Abe Sapien          True                 True               False
# Abin Sur           False                False                True
# Abomination        False                 True               False
# ...                  ...                  ...                 ...
# Yellowjacket II    False                False               False
# Ymir               False                False               False
# Yoda                True                False               False
# Zatanna            False                False               False
# Zoom               False                False               False
#
#                  Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# name
# 3-D Man                          False            False       False    False
# A-Bomb                           False            False        True    False
# Abe Sapien                       False             True        True    False
# Abin Sur                         False            False       False    False
# Abomination                      False            False       False    False
# ...                                ...              ...         ...      ...
# Yellowjacket II                  False            False       False    False
# Ymir                             False             True        True    False
# Yoda                             False            False       False     True
# Zatanna                          False            False       False    False
# Zoom                             False            False       False    False
#
#                  Energy Absorption  Flight  Danger Sense  ...  Web Creation  \
# name                                                      ...
# 3-D Man                      False   False         False  ...         False
# A-Bomb                       False   False         False  ...         False
# Abe Sapien                   False   False         False  ...         False
# Abin Sur                     False   False         False  ...         False
# Abomination                  False   False         False  ...         False
# ...                            ...     ...           ...  ...           ...
# Yellowjacket II              False    True         False  ...         False
# Ymir                         False   False         False  ...         False
# Yoda                         False   False          True  ...         False
# Zatanna                      False   False         False  ...         False
# Zoom                         False   False         False  ...         False
#
#                  Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# name
# 3-D Man                    False       False             False        False
# A-Bomb                     False       False             False        False
# Abe Sapien                 False       False             False        False
# Abin Sur                   False       False             False        False
# Abomination                False       False             False        False
# ...                          ...         ...               ...          ...
# Yellowjacket II            False       False             False        False
# Ymir                       False       False             False        False
# Yoda                       False       False             False        False
# Zatanna                    False       False             False        False
# Zoom                       False       False             False        False
#
#                  Phoenix Force  Molecular Dissipation  Vision - Cryo  \
# name
# 3-D Man                  False                  False          False
# A-Bomb                   False                  False          False
# Abe Sapien               False                  False          False
# Abin Sur                 False                  False          False
# Abomination              False                  False          False
# ...                        ...                    ...            ...
# Yellowjacket II          False                  False          False
# Ymir                     False                  False          False
# Yoda                     False                  False          False
# Zatanna                  False                  False          False
# Zoom                     False                  False          False
#
#                  Omnipresent  Omniscient
# name
# 3-D Man                False       False
# A-Bomb                 False       False
# Abe Sapien             False       False
# Abin Sur               False       False
# Abomination            False       False
# ...                      ...         ...
# Yellowjacket II        False       False
# Ymir                   False       False
# Yoda                   False       False
# Zatanna                False       False
# Zoom                   False       False
#
# [667 rows x 167 columns]

# %%
powers = list(powers_df.T.columns)
powers
# Out:
# ['Agility',
#  'Accelerated Healing',
#  'Lantern Power Ring',
#  'Dimensional Awareness',
#  'Cold Resistance',
#  'Durability',
#  'Stealth',
#  'Energy Absorption',
#  'Flight',
#  'Danger Sense',
#  'Underwater breathing',
#  'Marksmanship',
#  'Weapons Master',
#  'Power Augmentation',
#  'Animal Attributes',
#  'Longevity',
#  'Intelligence',
#  'Super Strength',
#  'Cryokinesis',
#  'Telepathy',
#  'Energy Armor',
#  'Energy Blasts',
#  'Duplication',
#  'Size Changing',
#  'Density Control',
#  'Stamina',
#  'Astral Travel',
#  'Audio Control',
#  'Dexterity',
#  'Omnitrix',
#  'Super Speed',
#  'Possession',
#  'Animal Oriented Powers',
#  'Weapon-based Powers',
#  'Electrokinesis',
#  'Darkforce Manipulation',
#  'Death Touch',
#  'Teleportation',
#  'Enhanced Senses',
#  'Telekinesis',
#  'Energy Beams',
#  'Magic',
#  'Hyperkinesis',
#  'Jump',
#  'Clairvoyance',
#  'Dimensional Travel',
#  'Power Sense',
#  'Shapeshifting',
#  'Peak Human Condition',
#  'Immortality',
#  'Camouflage',
#  'Element Control',
#  'Phasing',
#  'Astral Projection',
#  'Electrical Transport',
#  'Fire Control',
#  'Projection',
#  'Summoning',
#  'Enhanced Memory',
#  'Reflexes',
#  'Invulnerability',
#  'Energy Constructs',
#  'Force Fields',
#  'Self-Sustenance',
#  'Anti-Gravity',
#  'Empathy',
#  'Power Nullifier',
#  'Radiation Control',
#  'Psionic Powers',
#  'Elasticity',
#  'Substance Secretion',
#  'Elemental Transmogrification',
#  'Technopath/Cyberpath',
#  'Photographic Reflexes',
#  'Seismic Power',
#  'Animation',
#  'Precognition',
#  'Mind Control',
#  'Fire Resistance',
#  'Power Absorption',
#  'Enhanced Hearing',
#  'Nova Force',
#  'Insanity',
#  'Hypnokinesis',
#  'Animal Control',
#  'Natural Armor',
#  'Intangibility',
#  'Enhanced Sight',
#  'Molecular Manipulation',
#  'Heat Generation',
#  'Adaptation',
#  'Gliding',
#  'Power Suit',
#  'Mind Blast',
#  'Probability Manipulation',
#  'Gravity Control',
#  'Regeneration',
#  'Light Control',
#  'Echolocation',
#  'Levitation',
#  'Toxin and Disease Control',
#  'Banish',
#  'Energy Manipulation',
#  'Heat Resistance',
#  'Natural Weapons',
#  'Time Travel',
#  'Enhanced Smell',
#  'Illusions',
#  'Thirstokinesis',
#  'Hair Manipulation',
#  'Illumination',
#  'Omnipotent',
#  'Cloaking',
#  'Changing Armor',
#  'Power Cosmic',
#  'Biokinesis',
#  'Water Control',
#  'Radiation Immunity',
#  'Vision - Telescopic',
#  'Toxin and Disease Resistance',
#  'Spatial Awareness',
#  'Energy Resistance',
#  'Telepathy Resistance',
#  'Molecular Combustion',
#  'Omnilingualism',
#  'Portal Creation',
#  'Magnetism',
#  'Mind Control Resistance',
#  'Plant Control',
#  'Sonar',
#  'Sonic Scream',
#  'Time Manipulation',
#  'Enhanced Touch',
#  'Magic Resistance',
#  'Invisibility',
#  'Sub-Mariner',
#  'Radiation Absorption',
#  'Intuitive aptitude',
#  'Vision - Microscopic',
#  'Melting',
#  'Wind Control',
#  'Super Breath',
#  'Wallcrawling',
#  'Vision - Night',
#  'Vision - Infrared',
#  'Grim Reaping',
#  'Matter Absorption',
#  'The Force',
#  'Resurrection',
#  'Terrakinesis',
#  'Vision - Heat',
#  'Vitakinesis',
#  'Radar Sense',
#  'Qwardian Power Ring',
#  'Weather Control',
#  'Vision - X-Ray',
#  'Vision - Thermal',
#  'Web Creation',
#  'Reality Warping',
#  'Odin Force',
#  'Symbiote Costume',
#  'Speed Force',
#  'Phoenix Force',
#  'Molecular Dissipation',
#  'Vision - Cryo',
#  'Omnipresent',
#  'Omniscient']

# %%
heroes_df.isna().sum(axis=0)
# Out:
# name          0
# Gender        0
# Eye color     0
# Race          0
# Hair color    0
# Height        0
# Publisher     0
# Skin color    0
# Alignment     0
# Weight        0
# dtype: int64

# %%
heroes_and_powers_df["Power Count"]  = heroes_and_powers_df[powers].sum(axis=1)
heroes_and_powers_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 642  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 643             Ymir    Male     white        Frost Giant           No Hair
# 644             Yoda    Male     brown     Yoda's species             White
# 645          Zatanna  Female      blue              Human             Black
# 646             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  ...  \
# 0     203.0      Marvel Comics          -      good   441.0  ...
# 1     191.0  Dark Horse Comics       blue      good    65.0  ...
# 2     185.0          DC Comics        red      good    90.0  ...
# 3     203.0      Marvel Comics          -       bad   441.0  ...
# 4     -99.0      Marvel Comics          -       bad   -99.0  ...
# ..      ...                ...        ...       ...     ...  ...
# 642   165.0      Marvel Comics          -      good    52.0  ...
# 643   304.8      Marvel Comics      white      good   -99.0  ...
# 644    66.0       George Lucas      green      good    17.0  ...
# 645   170.0          DC Comics          -      good    57.0  ...
# 646   185.0          DC Comics          -       bad    81.0  ...
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0              False       False             False        False
# 1              False       False             False        False
# 2              False       False             False        False
# 3              False       False             False        False
# 4              False       False             False        False
# ..               ...         ...               ...          ...
# 642            False       False             False        False
# 643            False       False             False        False
# 644            False       False             False        False
# 645            False       False             False        False
# 646            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 4            False                  False          False        False
# ..             ...                    ...            ...          ...
# 642          False                  False          False        False
# 643          False                  False          False        False
# 644          False                  False          False        False
# 645          False                  False          False        False
# 646          False                  False          False        False
#
#      Omniscient  Power Count
# 0         False            7
# 1         False           16
# 2         False            1
# 3         False            8
# 4         False           14
# ..          ...          ...
# 642       False            3
# 643       False            6
# 644       False           19
# 645       False            8
# 646       False            4
#
# [647 rows x 178 columns]

# %%
heroes_and_powers_df[powers]
# Out:
#      Agility  Accelerated Healing  Lantern Power Ring  Dimensional Awareness  \
# 0      False                 True               False                  False
# 1       True                 True               False                  False
# 2      False                False                True                  False
# 3      False                 True               False                  False
# 4      False                False               False                   True
# ..       ...                  ...                 ...                    ...
# 642    False                False               False                  False
# 643    False                False               False                  False
# 644     True                False               False                  False
# 645    False                False               False                  False
# 646    False                False               False                  False
#
#      Cold Resistance  Durability  Stealth  Energy Absorption  Flight  \
# 0              False        True    False              False   False
# 1               True        True    False              False   False
# 2              False       False    False              False   False
# 3              False       False    False              False   False
# 4              False       False    False              False    True
# ..               ...         ...      ...                ...     ...
# 642            False       False    False              False    True
# 643             True        True    False              False   False
# 644            False       False     True              False   False
# 645            False       False    False              False   False
# 646            False       False    False              False   False
#
#      Danger Sense  ...  Web Creation  Reality Warping  Odin Force  \
# 0           False  ...         False            False       False
# 1           False  ...         False            False       False
# 2           False  ...         False            False       False
# 3           False  ...         False            False       False
# 4           False  ...         False            False       False
# ..            ...  ...           ...              ...         ...
# 642         False  ...         False            False       False
# 643         False  ...         False            False       False
# 644          True  ...         False            False       False
# 645         False  ...         False            False       False
# 646         False  ...         False            False       False
#
#      Symbiote Costume  Speed Force  Phoenix Force  Molecular Dissipation  \
# 0               False        False          False                  False
# 1               False        False          False                  False
# 2               False        False          False                  False
# 3               False        False          False                  False
# 4               False        False          False                  False
# ..                ...          ...            ...                    ...
# 642             False        False          False                  False
# 643             False        False          False                  False
# 644             False        False          False                  False
# 645             False        False          False                  False
# 646             False        False          False                  False
#
#      Vision - Cryo  Omnipresent  Omniscient
# 0            False        False       False
# 1            False        False       False
# 2            False        False       False
# 3            False        False       False
# 4            False        False       False
# ..             ...          ...         ...
# 642          False        False       False
# 643          False        False       False
# 644          False        False       False
# 645          False        False       False
# 646          False        False       False
#
# [647 rows x 167 columns]

# %% [markdown]
# ### Answering the Question
#
# Now we can plot the height vs. the count of powers:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(
    x=heroes_and_powers_df["Height"],
    y=heroes_and_powers_df["Power Count"],
    alpha=0.3
)

ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count");

# %% [markdown]
# Hmm...what is that stack of values off below zero? What is a "negative" height?

# %% [markdown]
# ### Identifying and Handling Invalid values
#
# One of the trickier tasks in data cleaning is identifying invalid or impossible values. In these cases, you have to apply your domain knowledge rather than any particular computational technique. For example, if you were looking at data containing dates of past home sales, and one of those dates was 100 years in the future, pandas wouldn't flag that as an issue, but you as a data scientist should be able to identify it.
#
# In this case, we are looking at heights, which are 1-dimensional, positive numbers. In theory we could have a very tiny height close to 0 cm because the hero is microscopic, but it does not make sense that we would have a height below zero.
#
# Let's take a look at a sample of those negative heights:

# %%
# Run this cell without changes
heroes_and_powers_df[heroes_and_powers_df["Height"] < 0]#.sample(5, random_state=1)
# Out:
#                  name  Gender Eye color           Race Hair color  Height  \
# 4             Abraxas    Male      blue  Cosmic Entity      Black   -99.0
# 6         Adam Monroe    Male      blue              -      Blond   -99.0
# 13        Alex Mercer    Male         -          Human          -   -99.0
# 14       Alex Woolsly    Male         -              -          -   -99.0
# 16   Allan Quatermain    Male         -              -          -   -99.0
# ..                ...     ...       ...            ...        ...     ...
# 618          Violator    Male         -              -          -   -99.0
# 629           Watcher    Male         -              -          -   -99.0
# 630         Weapon XI    Male         -              -          -   -99.0
# 631      White Canary  Female     brown          Human      Black   -99.0
# 632          Wildfire    Male         -              -          -   -99.0
#
#          Publisher Skin color Alignment  Weight  ...  Reality Warping  \
# 4    Marvel Comics          -       bad   -99.0  ...            False
# 6     NBC - Heroes          -      good   -99.0  ...            False
# 13       Wildstorm          -       bad   -99.0  ...            False
# 14    NBC - Heroes          -      good   -99.0  ...            False
# 16       Wildstorm          -      good   -99.0  ...            False
# ..             ...        ...       ...     ...  ...              ...
# 618   Image Comics          -       bad   -99.0  ...            False
# 629  Marvel Comics          -      good   -99.0  ...            False
# 630  Marvel Comics          -       bad   -99.0  ...            False
# 631      DC Comics          -       bad   -99.0  ...            False
# 632      DC Comics          -      good   -99.0  ...            False
#
#      Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# 4         False             False        False          False
# 6         False             False        False          False
# 13        False             False        False          False
# 14        False             False        False          False
# 16        False             False        False          False
# ..          ...               ...          ...            ...
# 618       False             False        False          False
# 629       False             False        False          False
# 630       False             False        False          False
# 631       False             False        False          False
# 632       False             False        False          False
#
#      Molecular Dissipation  Vision - Cryo  Omnipresent  Omniscient  \
# 4                    False          False        False       False
# 6                    False          False        False       False
# 13                   False          False        False       False
# 14                   False          False        False       False
# 16                   False          False        False       False
# ..                     ...            ...          ...         ...
# 618                  False          False        False       False
# 629                  False          False        False       False
# 630                  False          False        False       False
# 631                  False          False        False       False
# 632                  False          False        False       False
#
#      Power Count
# 4             14
# 6              3
# 13            27
# 14             1
# 16             1
# ..           ...
# 618            5
# 629           18
# 630            7
# 631            5
# 632            8
#
# [163 rows x 178 columns]

# %% [markdown]
# It looks like not only are those heights negative, those weights are negative also, and all of them are set to exactly -99.0.
#
# It seems like this data source probably filled in -99.0 as the height or weight whenever it was unknown, instead of just leaving it as NaN.
#
# Depending on the purpose of the analysis, maybe this would be a useful piece of information, but for our current question, let's go ahead and drop the records where the height is -99.0. We'll make a new temporary dataframe to make sure we don't accidentally delete anything that will be needed in a future question.

# %%
# Run this cell without changes
question_2_df = heroes_and_powers_df[heroes_and_powers_df["Height"] != -99.0].copy()
question_2_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 5      Absorbing Man    Male      blue              Human           No Hair
# ..               ...     ...       ...                ...               ...
# 642  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 643             Ymir    Male     white        Frost Giant           No Hair
# 644             Yoda    Male     brown     Yoda's species             White
# 645          Zatanna  Female      blue              Human             Black
# 646             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  ...  \
# 0     203.0      Marvel Comics          -      good   441.0  ...
# 1     191.0  Dark Horse Comics       blue      good    65.0  ...
# 2     185.0          DC Comics        red      good    90.0  ...
# 3     203.0      Marvel Comics          -       bad   441.0  ...
# 5     193.0      Marvel Comics          -       bad   122.0  ...
# ..      ...                ...        ...       ...     ...  ...
# 642   165.0      Marvel Comics          -      good    52.0  ...
# 643   304.8      Marvel Comics      white      good   -99.0  ...
# 644    66.0       George Lucas      green      good    17.0  ...
# 645   170.0          DC Comics          -      good    57.0  ...
# 646   185.0          DC Comics          -       bad    81.0  ...
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0              False       False             False        False
# 1              False       False             False        False
# 2              False       False             False        False
# 3              False       False             False        False
# 5              False       False             False        False
# ..               ...         ...               ...          ...
# 642            False       False             False        False
# 643            False       False             False        False
# 644            False       False             False        False
# 645            False       False             False        False
# 646            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 5            False                  False          False        False
# ..             ...                    ...            ...          ...
# 642          False                  False          False        False
# 643          False                  False          False        False
# 644          False                  False          False        False
# 645          False                  False          False        False
# 646          False                  False          False        False
#
#      Omniscient  Power Count
# 0         False            7
# 1         False           16
# 2         False            1
# 3         False            8
# 5         False           11
# ..          ...          ...
# 642       False            3
# 643       False            6
# 644       False           19
# 645       False            8
# 646       False            4
#
# [484 rows x 178 columns]

# %% [markdown]
# ### Answering the Question, Again
#
# Now we can redo that plot without those negative heights:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(
    x=question_2_df["Height"],
    y=question_2_df["Power Count"],
    alpha=0.3
)

ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count");

# %% [markdown]
# Ok, that makes more sense. It looks like there is not much of a relationship between height and number of superpowers.
#
# Now we can go on to answering the second half of question 2: *And does this differ based on gender?*
#
# To indicate multiple categories within a scatter plot, we can use color to add a third dimension:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

# Select subsets
question_2_male = question_2_df[question_2_df["Gender"] == "Male"]
question_2_female = question_2_df[question_2_df["Gender"] == "Female"]
question_2_other = question_2_df[(question_2_df["Gender"] != "Male") & (question_2_df["Gender"] != "Female")]

# Plot data with different colors
ax.scatter(
    x=question_2_male["Height"],
    y=question_2_male["Power Count"],
    alpha=0.5,
    color="cyan",
    label="Male"
)
ax.scatter(
    x=question_2_female["Height"],
    y=question_2_female["Power Count"],
    alpha=0.5,
    color="gray",
    label="Female"
)
ax.scatter(
    x=question_2_other["Height"],
    y=question_2_other["Power Count"],
    alpha=0.5,
    color="yellow",
    label="Other"
)

# Customize appearance
ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count")
ax.legend();

# %% [markdown]
# It appears that there is still no clear relationship between count of powers and height, regardless of gender. We do however note that "Male" is the most common gender, and that male superheroes tend to be taller, on average.

# %% [markdown]
# ## 4. Perform Data Aggregation Required to Answer Third Question
#
# Recall that the third question is: *What are the 5 most common superpowers in Marvel Comics vs. DC Comics?*
#
# We'll need to keep using `heroes_and_powers_df` since we require information from both `heroes_df` and `powers_df`.
#
# Your resulting `question_3_df` should contain aggregated data, with columns `Superpower Name`, `Marvel Comics` (containing the count of occurrences in Marvel Comics), and `DC Comics` (containing the count of occurrences in DC Comics). Each row should represent a superpower.
#
# In other words, `question_3_df` should look like this:
#
# ![question 3 df](images/question_3.png)
#
# Don't worry if the rows or columns are in a different order, all that matters is that you have the right rows and columns with all the data.
#
# ***Hint:*** refer to the [documentation for `.groupby`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html) and treat each publisher as a group.

# %%
# Your code here (create more cells as needed)
df = heroes_and_powers_df.copy()

# %%
df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 642  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 643             Ymir    Male     white        Frost Giant           No Hair
# 644             Yoda    Male     brown     Yoda's species             White
# 645          Zatanna  Female      blue              Human             Black
# 646             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  ...  \
# 0     203.0      Marvel Comics          -      good   441.0  ...
# 1     191.0  Dark Horse Comics       blue      good    65.0  ...
# 2     185.0          DC Comics        red      good    90.0  ...
# 3     203.0      Marvel Comics          -       bad   441.0  ...
# 4     -99.0      Marvel Comics          -       bad   -99.0  ...
# ..      ...                ...        ...       ...     ...  ...
# 642   165.0      Marvel Comics          -      good    52.0  ...
# 643   304.8      Marvel Comics      white      good   -99.0  ...
# 644    66.0       George Lucas      green      good    17.0  ...
# 645   170.0          DC Comics          -      good    57.0  ...
# 646   185.0          DC Comics          -       bad    81.0  ...
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0              False       False             False        False
# 1              False       False             False        False
# 2              False       False             False        False
# 3              False       False             False        False
# 4              False       False             False        False
# ..               ...         ...               ...          ...
# 642            False       False             False        False
# 643            False       False             False        False
# 644            False       False             False        False
# 645            False       False             False        False
# 646            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 4            False                  False          False        False
# ..             ...                    ...            ...          ...
# 642          False                  False          False        False
# 643          False                  False          False        False
# 644          False                  False          False        False
# 645          False                  False          False        False
# 646          False                  False          False        False
#
#      Omniscient  Power Count
# 0         False            7
# 1         False           16
# 2         False            1
# 3         False            8
# 4         False           14
# ..          ...          ...
# 642       False            3
# 643       False            6
# 644       False           19
# 645       False            8
# 646       False            4
#
# [647 rows x 178 columns]

# %%
powers_by_pub = df.groupby('Publisher').sum()[powers].T[['DC Comics','Marvel Comics']]
powers_by_pub = powers_by_pub.reset_index()
powers_by_pub.rename({'index':'Superpower Name'},axis=1,inplace=True)
powers_by_pub
# Out:
# Publisher        Superpower Name  DC Comics  Marvel Comics
# 0                        Agility         71            126
# 1            Accelerated Healing         51            100
# 2             Lantern Power Ring         11              0
# 3          Dimensional Awareness          7             16
# 4                Cold Resistance         15             25
# ..                           ...        ...            ...
# 162                Phoenix Force          0              1
# 163        Molecular Dissipation          1              0
# 164                Vision - Cryo          1              0
# 165                  Omnipresent          0              1
# 166                   Omniscient          0              1
#
# [167 rows x 3 columns]

# %%
powers_by_pub
# Out:
# Publisher              DC Comics  Marvel Comics
# Agility                       71            126
# Accelerated Healing           51            100
# Lantern Power Ring            11              0
# Dimensional Awareness          7             16
# Cold Resistance               15             25
# ...                          ...            ...
# Phoenix Force                  0              1
# Molecular Dissipation          1              0
# Vision - Cryo                  1              0
# Omnipresent                    0              1
# Omniscient                     0              1
#
# [167 rows x 2 columns]

# %%
powers_by_pub.reset_index()
# Out:
# Publisher                  index  DC Comics  Marvel Comics
# 0                        Agility         71            126
# 1            Accelerated Healing         51            100
# 2             Lantern Power Ring         11              0
# 3          Dimensional Awareness          7             16
# 4                Cold Resistance         15             25
# ..                           ...        ...            ...
# 162                Phoenix Force          0              1
# 163        Molecular Dissipation          1              0
# 164                Vision - Cryo          1              0
# 165                  Omnipresent          0              1
# 166                   Omniscient          0              1
#
# [167 rows x 3 columns]

# %% [markdown]
# ### JMI solution

# %%
df = heroes_and_powers_df.copy()
df

# %%
power_cols = powers_df_transposed.drop(columns='name').columns
power_cols

# %%
question_3_df = df.groupby('Publisher')[power_cols].sum().loc[[
    'DC Comics','Marvel Comics']].T.reset_index(drop=False)
question_3_df.rename({'index':'Superpower Name'},axis=1,inplace=True)
question_3_df

# %% [markdown]
# The code below checks that you have the correct dataframe structure:

# %%
question_3_df = powers_by_pub.copy()

# %%
# Run this cell without changes

# Checking that you made a dataframe called question_3_df
assert type(question_3_df) == pd.DataFrame

# Checking the shape
assert question_3_df.shape == (167, 3)

# Checking the column names
assert sorted(list(question_3_df.columns)) == ['DC Comics', 'Marvel Comics', 'Superpower Name']

# %% [markdown]
# ### Answering the Question
#
# The code below uses the dataframe you created to find and plot the most common superpowers in Marvel Comics and DC Comics.

# %%
question_3_df.set_index('Superpower Name',inplace=True)

# %%
question_3_df['DC Comics'].sort_values().tail(5).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Superpower Name'>

# %%
# Run this cell without changes

marvel_most_common = question_3_df.drop("DC Comics", axis=1)
marvel_most_common = marvel_most_common.sort_values(by="Marvel Comics", ascending=False)[:5]
marvel_most_common

# %%
# Run this cell without changes

dc_most_common = question_3_df.drop("Marvel Comics", axis=1)
dc_most_common = dc_most_common.sort_values(by="DC Comics", ascending=False)[:5]
dc_most_common

# %%
# Run this cell without changes

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 5))

ax1.bar(
    x=marvel_most_common["Superpower Name"],
    height=marvel_most_common["Marvel Comics"]
)
ax2.bar(
    x=dc_most_common["Superpower Name"],
    height=dc_most_common["DC Comics"]
)

ax1.set_ylabel("Count of Superheroes")
ax2.set_ylabel("Count of Superheroes")
ax1.set_title("Frequency of Top Superpowers in Marvel Comics")
ax2.set_title("Frequency of Top Superpowers in DC Comics");

# %% [markdown]
# It looks like super strength is the most popular power in both Marvel Comics and DC Comics. Overall, the top 5 powers are fairly similar — 4 out of 5 overlap, although Marvel contains agility whereas DC contains flight.

# %% [markdown]
# ## 5. Formulate and Answer Your Own Question
#
# For the remainder of this lab, you'll be focusing on coming up with and answering your own question, just like we did above.  Your question should not be overly simple, and should require both descriptive statistics and data visualization to answer.  In case you're unsure of what questions to ask, some sample questions have been provided below.
#
# Pick one of the following questions to investigate and answer, or come up with one of your own!
#
# * Which powers have the highest chance of co-occurring in a hero (e.g. super strength and flight)?
# * What is the distribution of skin colors amongst alien heroes?
# * How are eye color and hair color related in this dataset?
#
# Explain your question below:

# %%
corr = df[powers].corr()
corr
# Out:
#                         Agility  Accelerated Healing  Lantern Power Ring  \
# Agility                1.000000             0.285970            0.024530
# Accelerated Healing    0.285970             1.000000           -0.028693
# Lantern Power Ring     0.024530            -0.028693            1.000000
# Dimensional Awareness  0.031336             0.125167           -0.026366
# Cold Resistance        0.110763             0.146960           -0.037646
# ...                         ...                  ...                 ...
# Phoenix Force          0.051922            -0.024521           -0.005174
# Molecular Dissipation -0.029814             0.063130           -0.005174
# Vision - Cryo          0.051922             0.063130           -0.005174
# Omnipresent            0.015645             0.089349           -0.007323
# Omniscient             0.015645             0.089349           -0.007323
#
#                        Dimensional Awareness  Cold Resistance  Durability  \
# Agility                             0.031336         0.110763    0.135405
# Accelerated Healing                 0.125167         0.146960    0.256192
# Lantern Power Ring                 -0.026366        -0.037646   -0.008616
# Dimensional Awareness               1.000000        -0.057388   -0.047424
# Cold Resistance                    -0.057388         1.000000    0.270139
# ...                                      ...              ...         ...
# Phoenix Force                      -0.007888        -0.011262   -0.031836
# Molecular Dissipation              -0.007888        -0.011262    0.048624
# Vision - Cryo                      -0.007888        -0.011262    0.048624
# Omnipresent                         0.277754        -0.015940    0.011880
# Omniscient                          0.277754        -0.015940    0.011880
#
#                         Stealth  Energy Absorption    Flight  Danger Sense  \
# Agility                0.381410           0.042664 -0.006606      0.247563
# Accelerated Healing    0.102176           0.157619  0.124659      0.262432
# Lantern Power Ring    -0.064675          -0.047980  0.138041     -0.030489
# Dimensional Awareness  0.043161           0.126111  0.134232      0.026422
# Cold Resistance        0.051005           0.058863 -0.037134      0.013297
# ...                         ...                ...       ...           ...
# Phoenix Force         -0.019349           0.107844 -0.027370     -0.009121
# Molecular Dissipation -0.019349           0.107844  0.056557     -0.009121
# Vision - Cryo         -0.019349           0.107844  0.056557     -0.009121
# Omnipresent           -0.027384           0.152632  0.020654      0.113642
# Omniscient            -0.027384           0.152632  0.020654      0.113642
#
#                        ...  Web Creation  Reality Warping  Odin Force  \
# Agility                ...      0.148115         0.085918    0.073485
# Accelerated Healing    ...      0.233333         0.143965    0.089349
# Lantern Power Ring     ...     -0.020942        -0.019558   -0.007323
# Dimensional Awareness  ...      0.019713         0.576455   -0.011164
# Cold Resistance        ...     -0.045582        -0.002420   -0.015940
# ...                    ...           ...              ...         ...
# Phoenix Force          ...     -0.006265        -0.005851   -0.002191
# Molecular Dissipation  ...     -0.006265        -0.005851   -0.002191
# Vision - Cryo          ...     -0.006265        -0.005851   -0.002191
# Omnipresent            ...     -0.008867         0.374432   -0.003101
# Omniscient             ...     -0.008867         0.374432   -0.003101
#
#                        Symbiote Costume  Speed Force  Phoenix Force  \
# Agility                        0.113289     0.051922       0.051922
# Accelerated Healing            0.173128     0.063130      -0.024521
# Lantern Power Ring            -0.016478    -0.005174      -0.005174
# Dimensional Awareness          0.039889    -0.007888      -0.007888
# Cold Resistance                0.011492    -0.011262      -0.011262
# ...                                 ...          ...            ...
# Phoenix Force                 -0.004930    -0.001548       1.000000
# Molecular Dissipation         -0.004930    -0.001548      -0.001548
# Vision - Cryo                 -0.004930    -0.001548      -0.001548
# Omnipresent                   -0.006977    -0.002191      -0.002191
# Omniscient                    -0.006977    -0.002191      -0.002191
#
#                        Molecular Dissipation  Vision - Cryo  Omnipresent  \
# Agility                            -0.029814       0.051922     0.015645
# Accelerated Healing                 0.063130       0.063130     0.089349
# Lantern Power Ring                 -0.005174      -0.005174    -0.007323
# Dimensional Awareness              -0.007888      -0.007888     0.277754
# Cold Resistance                    -0.011262      -0.011262    -0.015940
# ...                                      ...            ...          ...
# Phoenix Force                      -0.001548      -0.001548    -0.002191
# Molecular Dissipation               1.000000      -0.001548    -0.002191
# Vision - Cryo                      -0.001548       1.000000    -0.002191
# Omnipresent                        -0.002191      -0.002191     1.000000
# Omniscient                         -0.002191      -0.002191     1.000000
#
#                        Omniscient
# Agility                  0.015645
# Accelerated Healing      0.089349
# Lantern Power Ring      -0.007323
# Dimensional Awareness    0.277754
# Cold Resistance         -0.015940
# ...                           ...
# Phoenix Force           -0.002191
# Molecular Dissipation   -0.002191
# Vision - Cryo           -0.002191
# Omnipresent              1.000000
# Omniscient               1.000000
#
# [167 rows x 167 columns]

# %%
corr_series = corr.unstack().reset_index()
corr_series.columns = ['power 1','power 2','corr']
corr_series
# Out:
#           power 1                power 2      corr
# 0         Agility                Agility  1.000000
# 1         Agility    Accelerated Healing  0.285970
# 2         Agility     Lantern Power Ring  0.024530
# 3         Agility  Dimensional Awareness  0.031336
# 4         Agility        Cold Resistance  0.110763
# ...           ...                    ...       ...
# 27884  Omniscient          Phoenix Force -0.002191
# 27885  Omniscient  Molecular Dissipation -0.002191
# 27886  Omniscient          Vision - Cryo -0.002191
# 27887  Omniscient            Omnipresent  1.000000
# 27888  Omniscient             Omniscient  1.000000
#
# [27889 rows x 3 columns]

# %%
corr_series = corr_series.sort_values('corr').dropna()
corr_series
# Out:
#                    power 1              power 2      corr
# 1348                Flight       Weapons Master -0.176541
# 2012        Weapons Master               Flight -0.176541
# 1342                Flight              Stealth -0.150620
# 1010               Stealth               Flight -0.150620
# 2851        Super Strength       Weapons Master -0.142994
# ...                    ...                  ...       ...
# 17808       Enhanced Smell       Enhanced Smell  1.000000
# 17640          Time Travel          Time Travel  1.000000
# 17472      Natural Weapons      Natural Weapons  1.000000
# 17136  Energy Manipulation  Energy Manipulation  1.000000
# 27888           Omniscient           Omniscient  1.000000
#
# [27556 rows x 3 columns]

# %%
corr_series = corr_series.loc[corr_series['power 1'] != corr_series['power 2']]
corr_series
# Out:
#                   power 1            power 2      corr
# 1348               Flight     Weapons Master -0.176541
# 2012       Weapons Master             Flight -0.176541
# 1342               Flight            Stealth -0.150620
# 1010              Stealth             Flight -0.150620
# 2851       Super Strength     Weapons Master -0.142994
# ...                   ...                ...       ...
# 23018  Intuitive aptitude            Melting  0.706559
# 27721         Omnipresent         Omniscient  1.000000
# 7134         Hyperkinesis  Spatial Awareness  1.000000
# 27887          Omniscient        Omnipresent  1.000000
# 20082   Spatial Awareness       Hyperkinesis  1.000000
#
# [27390 rows x 3 columns]

# %%
corr_series['power-unique'] = corr_series.apply(lambda row: ','.join(set(row[['power 1','power 2']] )),axis=1)
corr_series.drop_duplicates(subset=['power-unique'],inplace=True)
corr_series
# Out:
# <ipython-input-123-ec42411f4df4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corr_series['power-unique'] = corr_series.apply(lambda row: ','.join(set(row[['power 1','power 2']] )),axis=1)
# <ipython-input-123-ec42411f4df4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corr_series.drop_duplicates(subset=['power-unique'],inplace=True)
#                     power 1               power 2      corr  \
# 1348                 Flight        Weapons Master -0.176541
# 1342                 Flight               Stealth -0.150620
# 2851         Super Strength        Weapons Master -0.142994
# 8033   Peak Human Condition        Super Strength -0.141196
# 1384                 Flight  Peak Human Condition -0.137718
# ...                     ...                   ...       ...
# 23201  Vision - Microscopic        Vision - X-Ray  0.677610
# 23350               Melting    Intuitive aptitude  0.706559
# 23018    Intuitive aptitude               Melting  0.706559
# 27721           Omnipresent            Omniscient  1.000000
# 7134           Hyperkinesis     Spatial Awareness  1.000000
#
#                               power-unique
# 1348                 Flight,Weapons Master
# 1342                        Stealth,Flight
# 2851         Super Strength,Weapons Master
# 8033   Super Strength,Peak Human Condition
# 1384           Peak Human Condition,Flight
# ...                                    ...
# 23201  Vision - X-Ray,Vision - Microscopic
# 23350           Melting,Intuitive aptitude
# 23018           Intuitive aptitude,Melting
# 27721               Omnipresent,Omniscient
# 7134        Spatial Awareness,Hyperkinesis
#
# [14921 rows x 4 columns]

# %%
final_corr = corr_series[['power-unique','corr']].copy()
final_corr.sort_values('corr').set_index('power-unique').tail(5).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='power-unique'>

# %%
final_corr['powers'] = final_corr['power-unique'].str.split(',')
final_corr
# Out:
#                               power-unique      corr  \
# 1348                 Flight,Weapons Master -0.176541
# 1342                        Stealth,Flight -0.150620
# 2851         Super Strength,Weapons Master -0.142994
# 8033   Super Strength,Peak Human Condition -0.141196
# 1384           Peak Human Condition,Flight -0.137718
# ...                                    ...       ...
# 23201  Vision - X-Ray,Vision - Microscopic  0.677610
# 23350           Melting,Intuitive aptitude  0.706559
# 23018           Intuitive aptitude,Melting  0.706559
# 27721               Omnipresent,Omniscient  1.000000
# 7134        Spatial Awareness,Hyperkinesis  1.000000
#
#                                        powers
# 1348                 [Flight, Weapons Master]
# 1342                        [Stealth, Flight]
# 2851         [Super Strength, Weapons Master]
# 8033   [Super Strength, Peak Human Condition]
# 1384           [Peak Human Condition, Flight]
# ...                                       ...
# 23201  [Vision - X-Ray, Vision - Microscopic]
# 23350           [Melting, Intuitive aptitude]
# 23018           [Intuitive aptitude, Melting]
# 27721               [Omnipresent, Omniscient]
# 7134        [Spatial Awareness, Hyperkinesis]
#
# [14921 rows x 3 columns]

# %%
sns.barplot(data=final_corr.explode('powers'),x='powers',y='corr')
# Out:
# <AxesSubplot:xlabel='powers', ylabel='corr'>

# %%
# ex_row = corr_series.iloc[0]
# '-'.join(set(ex_row[['power 1','power 2']]))

# %%
list(corr.unstack().index)
# Out:
# [('Agility', 'Agility'),
#  ('Agility', 'Accelerated Healing'),
#  ('Agility', 'Lantern Power Ring'),
#  ('Agility', 'Dimensional Awareness'),
#  ('Agility', 'Cold Resistance'),
#  ('Agility', 'Durability'),
#  ('Agility', 'Stealth'),
#  ('Agility', 'Energy Absorption'),
#  ('Agility', 'Flight'),
#  ('Agility', 'Danger Sense'),
#  ('Agility', 'Underwater breathing'),
#  ('Agility', 'Marksmanship'),
#  ('Agility', 'Weapons Master'),
#  ('Agility', 'Power Augmentation'),
#  ('Agility', 'Animal Attributes'),
#  ('Agility', 'Longevity'),
#  ('Agility', 'Intelligence'),
#  ('Agility', 'Super Strength'),
#  ('Agility', 'Cryokinesis'),
#  ('Agility', 'Telepathy'),
#  ('Agility', 'Energy Armor'),
#  ('Agility', 'Energy Blasts'),
#  ('Agility', 'Duplication'),
#  ('Agility', 'Size Changing'),
#  ('Agility', 'Density Control'),
#  ('Agility', 'Stamina'),
#  ('Agility', 'Astral Travel'),
#  ('Agility', 'Audio Control'),
#  ('Agility', 'Dexterity'),
#  ('Agility', 'Omnitrix'),
#  ('Agility', 'Super Speed'),
#  ('Agility', 'Possession'),
#  ('Agility', 'Animal Oriented Powers'),
#  ('Agility', 'Weapon-based Powers'),
#  ('Agility', 'Electrokinesis'),
#  ('Agility', 'Darkforce Manipulation'),
#  ('Agility', 'Death Touch'),
#  ('Agility', 'Teleportation'),
#  ('Agility', 'Enhanced Senses'),
#  ('Agility', 'Telekinesis'),
#  ('Agility', 'Energy Beams'),
#  ('Agility', 'Magic'),
#  ('Agility', 'Hyperkinesis'),
#  ('Agility', 'Jump'),
#  ('Agility', 'Clairvoyance'),
#  ('Agility', 'Dimensional Travel'),
#  ('Agility', 'Power Sense'),
#  ('Agility', 'Shapeshifting'),
#  ('Agility', 'Peak Human Condition'),
#  ('Agility', 'Immortality'),
#  ('Agility', 'Camouflage'),
#  ('Agility', 'Element Control'),
#  ('Agility', 'Phasing'),
#  ('Agility', 'Astral Projection'),
#  ('Agility', 'Electrical Transport'),
#  ('Agility', 'Fire Control'),
#  ('Agility', 'Projection'),
#  ('Agility', 'Summoning'),
#  ('Agility', 'Enhanced Memory'),
#  ('Agility', 'Reflexes'),
#  ('Agility', 'Invulnerability'),
#  ('Agility', 'Energy Constructs'),
#  ('Agility', 'Force Fields'),
#  ('Agility', 'Self-Sustenance'),
#  ('Agility', 'Anti-Gravity'),
#  ('Agility', 'Empathy'),
#  ('Agility', 'Power Nullifier'),
#  ('Agility', 'Radiation Control'),
#  ('Agility', 'Psionic Powers'),
#  ('Agility', 'Elasticity'),
#  ('Agility', 'Substance Secretion'),
#  ('Agility', 'Elemental Transmogrification'),
#  ('Agility', 'Technopath/Cyberpath'),
#  ('Agility', 'Photographic Reflexes'),
#  ('Agility', 'Seismic Power'),
#  ('Agility', 'Animation'),
#  ('Agility', 'Precognition'),
#  ('Agility', 'Mind Control'),
#  ('Agility', 'Fire Resistance'),
#  ('Agility', 'Power Absorption'),
#  ('Agility', 'Enhanced Hearing'),
#  ('Agility', 'Nova Force'),
#  ('Agility', 'Insanity'),
#  ('Agility', 'Hypnokinesis'),
#  ('Agility', 'Animal Control'),
#  ('Agility', 'Natural Armor'),
#  ('Agility', 'Intangibility'),
#  ('Agility', 'Enhanced Sight'),
#  ('Agility', 'Molecular Manipulation'),
#  ('Agility', 'Heat Generation'),
#  ('Agility', 'Adaptation'),
#  ('Agility', 'Gliding'),
#  ('Agility', 'Power Suit'),
#  ('Agility', 'Mind Blast'),
#  ('Agility', 'Probability Manipulation'),
#  ('Agility', 'Gravity Control'),
#  ('Agility', 'Regeneration'),
#  ('Agility', 'Light Control'),
#  ('Agility', 'Echolocation'),
#  ('Agility', 'Levitation'),
#  ('Agility', 'Toxin and Disease Control'),
#  ('Agility', 'Banish'),
#  ('Agility', 'Energy Manipulation'),
#  ('Agility', 'Heat Resistance'),
#  ('Agility', 'Natural Weapons'),
#  ('Agility', 'Time Travel'),
#  ('Agility', 'Enhanced Smell'),
#  ('Agility', 'Illusions'),
#  ('Agility', 'Thirstokinesis'),
#  ('Agility', 'Hair Manipulation'),
#  ('Agility', 'Illumination'),
#  ('Agility', 'Omnipotent'),
#  ('Agility', 'Cloaking'),
#  ('Agility', 'Changing Armor'),
#  ('Agility', 'Power Cosmic'),
#  ('Agility', 'Biokinesis'),
#  ('Agility', 'Water Control'),
#  ('Agility', 'Radiation Immunity'),
#  ('Agility', 'Vision - Telescopic'),
#  ('Agility', 'Toxin and Disease Resistance'),
#  ('Agility', 'Spatial Awareness'),
#  ('Agility', 'Energy Resistance'),
#  ('Agility', 'Telepathy Resistance'),
#  ('Agility', 'Molecular Combustion'),
#  ('Agility', 'Omnilingualism'),
#  ('Agility', 'Portal Creation'),
#  ('Agility', 'Magnetism'),
#  ('Agility', 'Mind Control Resistance'),
#  ('Agility', 'Plant Control'),
#  ('Agility', 'Sonar'),
#  ('Agility', 'Sonic Scream'),
#  ('Agility', 'Time Manipulation'),
#  ('Agility', 'Enhanced Touch'),
#  ('Agility', 'Magic Resistance'),
#  ('Agility', 'Invisibility'),
#  ('Agility', 'Sub-Mariner'),
#  ('Agility', 'Radiation Absorption'),
#  ('Agility', 'Intuitive aptitude'),
#  ('Agility', 'Vision - Microscopic'),
#  ('Agility', 'Melting'),
#  ('Agility', 'Wind Control'),
#  ('Agility', 'Super Breath'),
#  ('Agility', 'Wallcrawling'),
#  ('Agility', 'Vision - Night'),
#  ('Agility', 'Vision - Infrared'),
#  ('Agility', 'Grim Reaping'),
#  ('Agility', 'Matter Absorption'),
#  ('Agility', 'The Force'),
#  ('Agility', 'Resurrection'),
#  ('Agility', 'Terrakinesis'),
#  ('Agility', 'Vision - Heat'),
#  ('Agility', 'Vitakinesis'),
#  ('Agility', 'Radar Sense'),
#  ('Agility', 'Qwardian Power Ring'),
#  ('Agility', 'Weather Control'),
#  ('Agility', 'Vision - X-Ray'),
#  ('Agility', 'Vision - Thermal'),
#  ('Agility', 'Web Creation'),
#  ('Agility', 'Reality Warping'),
#  ('Agility', 'Odin Force'),
#  ('Agility', 'Symbiote Costume'),
#  ('Agility', 'Speed Force'),
#  ('Agility', 'Phoenix Force'),
#  ('Agility', 'Molecular Dissipation'),
#  ('Agility', 'Vision - Cryo'),
#  ('Agility', 'Omnipresent'),
#  ('Agility', 'Omniscient'),
#  ('Accelerated Healing', 'Agility'),
#  ('Accelerated Healing', 'Accelerated Healing'),
#  ('Accelerated Healing', 'Lantern Power Ring'),
#  ('Accelerated Healing', 'Dimensional Awareness'),
#  ('Accelerated Healing', 'Cold Resistance'),
#  ('Accelerated Healing', 'Durability'),
#  ('Accelerated Healing', 'Stealth'),
#  ('Accelerated Healing', 'Energy Absorption'),
#  ('Accelerated Healing', 'Flight'),
#  ('Accelerated Healing', 'Danger Sense'),
#  ('Accelerated Healing', 'Underwater breathing'),
#  ('Accelerated Healing', 'Marksmanship'),
#  ('Accelerated Healing', 'Weapons Master'),
#  ('Accelerated Healing', 'Power Augmentation'),
#  ('Accelerated Healing', 'Animal Attributes'),
#  ('Accelerated Healing', 'Longevity'),
#  ('Accelerated Healing', 'Intelligence'),
#  ('Accelerated Healing', 'Super Strength'),
#  ('Accelerated Healing', 'Cryokinesis'),
#  ('Accelerated Healing', 'Telepathy'),
#  ('Accelerated Healing', 'Energy Armor'),
#  ('Accelerated Healing', 'Energy Blasts'),
#  ('Accelerated Healing', 'Duplication'),
#  ('Accelerated Healing', 'Size Changing'),
#  ('Accelerated Healing', 'Density Control'),
#  ('Accelerated Healing', 'Stamina'),
#  ('Accelerated Healing', 'Astral Travel'),
#  ('Accelerated Healing', 'Audio Control'),
#  ('Accelerated Healing', 'Dexterity'),
#  ('Accelerated Healing', 'Omnitrix'),
#  ('Accelerated Healing', 'Super Speed'),
#  ('Accelerated Healing', 'Possession'),
#  ('Accelerated Healing', 'Animal Oriented Powers'),
#  ('Accelerated Healing', 'Weapon-based Powers'),
#  ('Accelerated Healing', 'Electrokinesis'),
#  ('Accelerated Healing', 'Darkforce Manipulation'),
#  ('Accelerated Healing', 'Death Touch'),
#  ('Accelerated Healing', 'Teleportation'),
#  ('Accelerated Healing', 'Enhanced Senses'),
#  ('Accelerated Healing', 'Telekinesis'),
#  ('Accelerated Healing', 'Energy Beams'),
#  ('Accelerated Healing', 'Magic'),
#  ('Accelerated Healing', 'Hyperkinesis'),
#  ('Accelerated Healing', 'Jump'),
#  ('Accelerated Healing', 'Clairvoyance'),
#  ('Accelerated Healing', 'Dimensional Travel'),
#  ('Accelerated Healing', 'Power Sense'),
#  ('Accelerated Healing', 'Shapeshifting'),
#  ('Accelerated Healing', 'Peak Human Condition'),
#  ('Accelerated Healing', 'Immortality'),
#  ('Accelerated Healing', 'Camouflage'),
#  ('Accelerated Healing', 'Element Control'),
#  ('Accelerated Healing', 'Phasing'),
#  ('Accelerated Healing', 'Astral Projection'),
#  ('Accelerated Healing', 'Electrical Transport'),
#  ('Accelerated Healing', 'Fire Control'),
#  ('Accelerated Healing', 'Projection'),
#  ('Accelerated Healing', 'Summoning'),
#  ('Accelerated Healing', 'Enhanced Memory'),
#  ('Accelerated Healing', 'Reflexes'),
#  ('Accelerated Healing', 'Invulnerability'),
#  ('Accelerated Healing', 'Energy Constructs'),
#  ('Accelerated Healing', 'Force Fields'),
#  ('Accelerated Healing', 'Self-Sustenance'),
#  ('Accelerated Healing', 'Anti-Gravity'),
#  ('Accelerated Healing', 'Empathy'),
#  ('Accelerated Healing', 'Power Nullifier'),
#  ('Accelerated Healing', 'Radiation Control'),
#  ('Accelerated Healing', 'Psionic Powers'),
#  ('Accelerated Healing', 'Elasticity'),
#  ('Accelerated Healing', 'Substance Secretion'),
#  ('Accelerated Healing', 'Elemental Transmogrification'),
#  ('Accelerated Healing', 'Technopath/Cyberpath'),
#  ('Accelerated Healing', 'Photographic Reflexes'),
#  ('Accelerated Healing', 'Seismic Power'),
#  ('Accelerated Healing', 'Animation'),
#  ('Accelerated Healing', 'Precognition'),
#  ('Accelerated Healing', 'Mind Control'),
#  ('Accelerated Healing', 'Fire Resistance'),
#  ('Accelerated Healing', 'Power Absorption'),
#  ('Accelerated Healing', 'Enhanced Hearing'),
#  ('Accelerated Healing', 'Nova Force'),
#  ('Accelerated Healing', 'Insanity'),
#  ('Accelerated Healing', 'Hypnokinesis'),
#  ('Accelerated Healing', 'Animal Control'),
#  ('Accelerated Healing', 'Natural Armor'),
#  ('Accelerated Healing', 'Intangibility'),
#  ('Accelerated Healing', 'Enhanced Sight'),
#  ('Accelerated Healing', 'Molecular Manipulation'),
#  ('Accelerated Healing', 'Heat Generation'),
#  ('Accelerated Healing', 'Adaptation'),
#  ('Accelerated Healing', 'Gliding'),
#  ('Accelerated Healing', 'Power Suit'),
#  ('Accelerated Healing', 'Mind Blast'),
#  ('Accelerated Healing', 'Probability Manipulation'),
#  ('Accelerated Healing', 'Gravity Control'),
#  ('Accelerated Healing', 'Regeneration'),
#  ('Accelerated Healing', 'Light Control'),
#  ('Accelerated Healing', 'Echolocation'),
#  ('Accelerated Healing', 'Levitation'),
#  ('Accelerated Healing', 'Toxin and Disease Control'),
#  ('Accelerated Healing', 'Banish'),
#  ('Accelerated Healing', 'Energy Manipulation'),
#  ('Accelerated Healing', 'Heat Resistance'),
#  ('Accelerated Healing', 'Natural Weapons'),
#  ('Accelerated Healing', 'Time Travel'),
#  ('Accelerated Healing', 'Enhanced Smell'),
#  ('Accelerated Healing', 'Illusions'),
#  ('Accelerated Healing', 'Thirstokinesis'),
#  ('Accelerated Healing', 'Hair Manipulation'),
#  ('Accelerated Healing', 'Illumination'),
#  ('Accelerated Healing', 'Omnipotent'),
#  ('Accelerated Healing', 'Cloaking'),
#  ('Accelerated Healing', 'Changing Armor'),
#  ('Accelerated Healing', 'Power Cosmic'),
#  ('Accelerated Healing', 'Biokinesis'),
#  ('Accelerated Healing', 'Water Control'),
#  ('Accelerated Healing', 'Radiation Immunity'),
#  ('Accelerated Healing', 'Vision - Telescopic'),
#  ('Accelerated Healing', 'Toxin and Disease Resistance'),
#  ('Accelerated Healing', 'Spatial Awareness'),
#  ('Accelerated Healing', 'Energy Resistance'),
#  ('Accelerated Healing', 'Telepathy Resistance'),
#  ('Accelerated Healing', 'Molecular Combustion'),
#  ('Accelerated Healing', 'Omnilingualism'),
#  ('Accelerated Healing', 'Portal Creation'),
#  ('Accelerated Healing', 'Magnetism'),
#  ('Accelerated Healing', 'Mind Control Resistance'),
#  ('Accelerated Healing', 'Plant Control'),
#  ('Accelerated Healing', 'Sonar'),
#  ('Accelerated Healing', 'Sonic Scream'),
#  ('Accelerated Healing', 'Time Manipulation'),
#  ('Accelerated Healing', 'Enhanced Touch'),
#  ('Accelerated Healing', 'Magic Resistance'),
#  ('Accelerated Healing', 'Invisibility'),
#  ('Accelerated Healing', 'Sub-Mariner'),
#  ('Accelerated Healing', 'Radiation Absorption'),
#  ('Accelerated Healing', 'Intuitive aptitude'),
#  ('Accelerated Healing', 'Vision - Microscopic'),
#  ('Accelerated Healing', 'Melting'),
#  ('Accelerated Healing', 'Wind Control'),
#  ('Accelerated Healing', 'Super Breath'),
#  ('Accelerated Healing', 'Wallcrawling'),
#  ('Accelerated Healing', 'Vision - Night'),
#  ('Accelerated Healing', 'Vision - Infrared'),
#  ('Accelerated Healing', 'Grim Reaping'),
#  ('Accelerated Healing', 'Matter Absorption'),
#  ('Accelerated Healing', 'The Force'),
#  ('Accelerated Healing', 'Resurrection'),
#  ('Accelerated Healing', 'Terrakinesis'),
#  ('Accelerated Healing', 'Vision - Heat'),
#  ('Accelerated Healing', 'Vitakinesis'),
#  ('Accelerated Healing', 'Radar Sense'),
#  ('Accelerated Healing', 'Qwardian Power Ring'),
#  ('Accelerated Healing', 'Weather Control'),
#  ('Accelerated Healing', 'Vision - X-Ray'),
#  ('Accelerated Healing', 'Vision - Thermal'),
#  ('Accelerated Healing', 'Web Creation'),
#  ('Accelerated Healing', 'Reality Warping'),
#  ('Accelerated Healing', 'Odin Force'),
#  ('Accelerated Healing', 'Symbiote Costume'),
#  ('Accelerated Healing', 'Speed Force'),
#  ('Accelerated Healing', 'Phoenix Force'),
#  ('Accelerated Healing', 'Molecular Dissipation'),
#  ('Accelerated Healing', 'Vision - Cryo'),
#  ('Accelerated Healing', 'Omnipresent'),
#  ('Accelerated Healing', 'Omniscient'),
#  ('Lantern Power Ring', 'Agility'),
#  ('Lantern Power Ring', 'Accelerated Healing'),
#  ('Lantern Power Ring', 'Lantern Power Ring'),
#  ('Lantern Power Ring', 'Dimensional Awareness'),
#  ('Lantern Power Ring', 'Cold Resistance'),
#  ('Lantern Power Ring', 'Durability'),
#  ('Lantern Power Ring', 'Stealth'),
#  ('Lantern Power Ring', 'Energy Absorption'),
#  ('Lantern Power Ring', 'Flight'),
#  ('Lantern Power Ring', 'Danger Sense'),
#  ('Lantern Power Ring', 'Underwater breathing'),
#  ('Lantern Power Ring', 'Marksmanship'),
#  ('Lantern Power Ring', 'Weapons Master'),
#  ('Lantern Power Ring', 'Power Augmentation'),
#  ('Lantern Power Ring', 'Animal Attributes'),
#  ('Lantern Power Ring', 'Longevity'),
#  ('Lantern Power Ring', 'Intelligence'),
#  ('Lantern Power Ring', 'Super Strength'),
#  ('Lantern Power Ring', 'Cryokinesis'),
#  ('Lantern Power Ring', 'Telepathy'),
#  ('Lantern Power Ring', 'Energy Armor'),
#  ('Lantern Power Ring', 'Energy Blasts'),
#  ('Lantern Power Ring', 'Duplication'),
#  ('Lantern Power Ring', 'Size Changing'),
#  ('Lantern Power Ring', 'Density Control'),
#  ('Lantern Power Ring', 'Stamina'),
#  ('Lantern Power Ring', 'Astral Travel'),
#  ('Lantern Power Ring', 'Audio Control'),
#  ('Lantern Power Ring', 'Dexterity'),
#  ('Lantern Power Ring', 'Omnitrix'),
#  ('Lantern Power Ring', 'Super Speed'),
#  ('Lantern Power Ring', 'Possession'),
#  ('Lantern Power Ring', 'Animal Oriented Powers'),
#  ('Lantern Power Ring', 'Weapon-based Powers'),
#  ('Lantern Power Ring', 'Electrokinesis'),
#  ('Lantern Power Ring', 'Darkforce Manipulation'),
#  ('Lantern Power Ring', 'Death Touch'),
#  ('Lantern Power Ring', 'Teleportation'),
#  ('Lantern Power Ring', 'Enhanced Senses'),
#  ('Lantern Power Ring', 'Telekinesis'),
#  ('Lantern Power Ring', 'Energy Beams'),
#  ('Lantern Power Ring', 'Magic'),
#  ('Lantern Power Ring', 'Hyperkinesis'),
#  ('Lantern Power Ring', 'Jump'),
#  ('Lantern Power Ring', 'Clairvoyance'),
#  ('Lantern Power Ring', 'Dimensional Travel'),
#  ('Lantern Power Ring', 'Power Sense'),
#  ('Lantern Power Ring', 'Shapeshifting'),
#  ('Lantern Power Ring', 'Peak Human Condition'),
#  ('Lantern Power Ring', 'Immortality'),
#  ('Lantern Power Ring', 'Camouflage'),
#  ('Lantern Power Ring', 'Element Control'),
#  ('Lantern Power Ring', 'Phasing'),
#  ('Lantern Power Ring', 'Astral Projection'),
#  ('Lantern Power Ring', 'Electrical Transport'),
#  ('Lantern Power Ring', 'Fire Control'),
#  ('Lantern Power Ring', 'Projection'),
#  ('Lantern Power Ring', 'Summoning'),
#  ('Lantern Power Ring', 'Enhanced Memory'),
#  ('Lantern Power Ring', 'Reflexes'),
#  ('Lantern Power Ring', 'Invulnerability'),
#  ('Lantern Power Ring', 'Energy Constructs'),
#  ('Lantern Power Ring', 'Force Fields'),
#  ('Lantern Power Ring', 'Self-Sustenance'),
#  ('Lantern Power Ring', 'Anti-Gravity'),
#  ('Lantern Power Ring', 'Empathy'),
#  ('Lantern Power Ring', 'Power Nullifier'),
#  ('Lantern Power Ring', 'Radiation Control'),
#  ('Lantern Power Ring', 'Psionic Powers'),
#  ('Lantern Power Ring', 'Elasticity'),
#  ('Lantern Power Ring', 'Substance Secretion'),
#  ('Lantern Power Ring', 'Elemental Transmogrification'),
#  ('Lantern Power Ring', 'Technopath/Cyberpath'),
#  ('Lantern Power Ring', 'Photographic Reflexes'),
#  ('Lantern Power Ring', 'Seismic Power'),
#  ('Lantern Power Ring', 'Animation'),
#  ('Lantern Power Ring', 'Precognition'),
#  ('Lantern Power Ring', 'Mind Control'),
#  ('Lantern Power Ring', 'Fire Resistance'),
#  ('Lantern Power Ring', 'Power Absorption'),
#  ('Lantern Power Ring', 'Enhanced Hearing'),
#  ('Lantern Power Ring', 'Nova Force'),
#  ('Lantern Power Ring', 'Insanity'),
#  ('Lantern Power Ring', 'Hypnokinesis'),
#  ('Lantern Power Ring', 'Animal Control'),
#  ('Lantern Power Ring', 'Natural Armor'),
#  ('Lantern Power Ring', 'Intangibility'),
#  ('Lantern Power Ring', 'Enhanced Sight'),
#  ('Lantern Power Ring', 'Molecular Manipulation'),
#  ('Lantern Power Ring', 'Heat Generation'),
#  ('Lantern Power Ring', 'Adaptation'),
#  ('Lantern Power Ring', 'Gliding'),
#  ('Lantern Power Ring', 'Power Suit'),
#  ('Lantern Power Ring', 'Mind Blast'),
#  ('Lantern Power Ring', 'Probability Manipulation'),
#  ('Lantern Power Ring', 'Gravity Control'),
#  ('Lantern Power Ring', 'Regeneration'),
#  ('Lantern Power Ring', 'Light Control'),
#  ('Lantern Power Ring', 'Echolocation'),
#  ('Lantern Power Ring', 'Levitation'),
#  ('Lantern Power Ring', 'Toxin and Disease Control'),
#  ('Lantern Power Ring', 'Banish'),
#  ('Lantern Power Ring', 'Energy Manipulation'),
#  ('Lantern Power Ring', 'Heat Resistance'),
#  ('Lantern Power Ring', 'Natural Weapons'),
#  ('Lantern Power Ring', 'Time Travel'),
#  ('Lantern Power Ring', 'Enhanced Smell'),
#  ('Lantern Power Ring', 'Illusions'),
#  ('Lantern Power Ring', 'Thirstokinesis'),
#  ('Lantern Power Ring', 'Hair Manipulation'),
#  ('Lantern Power Ring', 'Illumination'),
#  ('Lantern Power Ring', 'Omnipotent'),
#  ('Lantern Power Ring', 'Cloaking'),
#  ('Lantern Power Ring', 'Changing Armor'),
#  ('Lantern Power Ring', 'Power Cosmic'),
#  ('Lantern Power Ring', 'Biokinesis'),
#  ('Lantern Power Ring', 'Water Control'),
#  ('Lantern Power Ring', 'Radiation Immunity'),
#  ('Lantern Power Ring', 'Vision - Telescopic'),
#  ('Lantern Power Ring', 'Toxin and Disease Resistance'),
#  ('Lantern Power Ring', 'Spatial Awareness'),
#  ('Lantern Power Ring', 'Energy Resistance'),
#  ('Lantern Power Ring', 'Telepathy Resistance'),
#  ('Lantern Power Ring', 'Molecular Combustion'),
#  ('Lantern Power Ring', 'Omnilingualism'),
#  ('Lantern Power Ring', 'Portal Creation'),
#  ('Lantern Power Ring', 'Magnetism'),
#  ('Lantern Power Ring', 'Mind Control Resistance'),
#  ('Lantern Power Ring', 'Plant Control'),
#  ('Lantern Power Ring', 'Sonar'),
#  ('Lantern Power Ring', 'Sonic Scream'),
#  ('Lantern Power Ring', 'Time Manipulation'),
#  ('Lantern Power Ring', 'Enhanced Touch'),
#  ('Lantern Power Ring', 'Magic Resistance'),
#  ('Lantern Power Ring', 'Invisibility'),
#  ('Lantern Power Ring', 'Sub-Mariner'),
#  ('Lantern Power Ring', 'Radiation Absorption'),
#  ('Lantern Power Ring', 'Intuitive aptitude'),
#  ('Lantern Power Ring', 'Vision - Microscopic'),
#  ('Lantern Power Ring', 'Melting'),
#  ('Lantern Power Ring', 'Wind Control'),
#  ('Lantern Power Ring', 'Super Breath'),
#  ('Lantern Power Ring', 'Wallcrawling'),
#  ('Lantern Power Ring', 'Vision - Night'),
#  ('Lantern Power Ring', 'Vision - Infrared'),
#  ('Lantern Power Ring', 'Grim Reaping'),
#  ('Lantern Power Ring', 'Matter Absorption'),
#  ('Lantern Power Ring', 'The Force'),
#  ('Lantern Power Ring', 'Resurrection'),
#  ('Lantern Power Ring', 'Terrakinesis'),
#  ('Lantern Power Ring', 'Vision - Heat'),
#  ('Lantern Power Ring', 'Vitakinesis'),
#  ('Lantern Power Ring', 'Radar Sense'),
#  ('Lantern Power Ring', 'Qwardian Power Ring'),
#  ('Lantern Power Ring', 'Weather Control'),
#  ('Lantern Power Ring', 'Vision - X-Ray'),
#  ('Lantern Power Ring', 'Vision - Thermal'),
#  ('Lantern Power Ring', 'Web Creation'),
#  ('Lantern Power Ring', 'Reality Warping'),
#  ('Lantern Power Ring', 'Odin Force'),
#  ('Lantern Power Ring', 'Symbiote Costume'),
#  ('Lantern Power Ring', 'Speed Force'),
#  ('Lantern Power Ring', 'Phoenix Force'),
#  ('Lantern Power Ring', 'Molecular Dissipation'),
#  ('Lantern Power Ring', 'Vision - Cryo'),
#  ('Lantern Power Ring', 'Omnipresent'),
#  ('Lantern Power Ring', 'Omniscient'),
#  ('Dimensional Awareness', 'Agility'),
#  ('Dimensional Awareness', 'Accelerated Healing'),
#  ('Dimensional Awareness', 'Lantern Power Ring'),
#  ('Dimensional Awareness', 'Dimensional Awareness'),
#  ('Dimensional Awareness', 'Cold Resistance'),
#  ('Dimensional Awareness', 'Durability'),
#  ('Dimensional Awareness', 'Stealth'),
#  ('Dimensional Awareness', 'Energy Absorption'),
#  ('Dimensional Awareness', 'Flight'),
#  ('Dimensional Awareness', 'Danger Sense'),
#  ('Dimensional Awareness', 'Underwater breathing'),
#  ('Dimensional Awareness', 'Marksmanship'),
#  ('Dimensional Awareness', 'Weapons Master'),
#  ('Dimensional Awareness', 'Power Augmentation'),
#  ('Dimensional Awareness', 'Animal Attributes'),
#  ('Dimensional Awareness', 'Longevity'),
#  ('Dimensional Awareness', 'Intelligence'),
#  ('Dimensional Awareness', 'Super Strength'),
#  ('Dimensional Awareness', 'Cryokinesis'),
#  ('Dimensional Awareness', 'Telepathy'),
#  ('Dimensional Awareness', 'Energy Armor'),
#  ('Dimensional Awareness', 'Energy Blasts'),
#  ('Dimensional Awareness', 'Duplication'),
#  ('Dimensional Awareness', 'Size Changing'),
#  ('Dimensional Awareness', 'Density Control'),
#  ('Dimensional Awareness', 'Stamina'),
#  ('Dimensional Awareness', 'Astral Travel'),
#  ('Dimensional Awareness', 'Audio Control'),
#  ('Dimensional Awareness', 'Dexterity'),
#  ('Dimensional Awareness', 'Omnitrix'),
#  ('Dimensional Awareness', 'Super Speed'),
#  ('Dimensional Awareness', 'Possession'),
#  ('Dimensional Awareness', 'Animal Oriented Powers'),
#  ('Dimensional Awareness', 'Weapon-based Powers'),
#  ('Dimensional Awareness', 'Electrokinesis'),
#  ('Dimensional Awareness', 'Darkforce Manipulation'),
#  ('Dimensional Awareness', 'Death Touch'),
#  ('Dimensional Awareness', 'Teleportation'),
#  ('Dimensional Awareness', 'Enhanced Senses'),
#  ('Dimensional Awareness', 'Telekinesis'),
#  ('Dimensional Awareness', 'Energy Beams'),
#  ('Dimensional Awareness', 'Magic'),
#  ('Dimensional Awareness', 'Hyperkinesis'),
#  ('Dimensional Awareness', 'Jump'),
#  ('Dimensional Awareness', 'Clairvoyance'),
#  ('Dimensional Awareness', 'Dimensional Travel'),
#  ('Dimensional Awareness', 'Power Sense'),
#  ('Dimensional Awareness', 'Shapeshifting'),
#  ('Dimensional Awareness', 'Peak Human Condition'),
#  ('Dimensional Awareness', 'Immortality'),
#  ('Dimensional Awareness', 'Camouflage'),
#  ('Dimensional Awareness', 'Element Control'),
#  ('Dimensional Awareness', 'Phasing'),
#  ('Dimensional Awareness', 'Astral Projection'),
#  ('Dimensional Awareness', 'Electrical Transport'),
#  ('Dimensional Awareness', 'Fire Control'),
#  ('Dimensional Awareness', 'Projection'),
#  ('Dimensional Awareness', 'Summoning'),
#  ('Dimensional Awareness', 'Enhanced Memory'),
#  ('Dimensional Awareness', 'Reflexes'),
#  ('Dimensional Awareness', 'Invulnerability'),
#  ('Dimensional Awareness', 'Energy Constructs'),
#  ('Dimensional Awareness', 'Force Fields'),
#  ('Dimensional Awareness', 'Self-Sustenance'),
#  ('Dimensional Awareness', 'Anti-Gravity'),
#  ('Dimensional Awareness', 'Empathy'),
#  ('Dimensional Awareness', 'Power Nullifier'),
#  ('Dimensional Awareness', 'Radiation Control'),
#  ('Dimensional Awareness', 'Psionic Powers'),
#  ('Dimensional Awareness', 'Elasticity'),
#  ('Dimensional Awareness', 'Substance Secretion'),
#  ('Dimensional Awareness', 'Elemental Transmogrification'),
#  ('Dimensional Awareness', 'Technopath/Cyberpath'),
#  ('Dimensional Awareness', 'Photographic Reflexes'),
#  ('Dimensional Awareness', 'Seismic Power'),
#  ('Dimensional Awareness', 'Animation'),
#  ('Dimensional Awareness', 'Precognition'),
#  ('Dimensional Awareness', 'Mind Control'),
#  ('Dimensional Awareness', 'Fire Resistance'),
#  ('Dimensional Awareness', 'Power Absorption'),
#  ('Dimensional Awareness', 'Enhanced Hearing'),
#  ('Dimensional Awareness', 'Nova Force'),
#  ('Dimensional Awareness', 'Insanity'),
#  ('Dimensional Awareness', 'Hypnokinesis'),
#  ('Dimensional Awareness', 'Animal Control'),
#  ('Dimensional Awareness', 'Natural Armor'),
#  ('Dimensional Awareness', 'Intangibility'),
#  ('Dimensional Awareness', 'Enhanced Sight'),
#  ('Dimensional Awareness', 'Molecular Manipulation'),
#  ('Dimensional Awareness', 'Heat Generation'),
#  ('Dimensional Awareness', 'Adaptation'),
#  ('Dimensional Awareness', 'Gliding'),
#  ('Dimensional Awareness', 'Power Suit'),
#  ('Dimensional Awareness', 'Mind Blast'),
#  ('Dimensional Awareness', 'Probability Manipulation'),
#  ('Dimensional Awareness', 'Gravity Control'),
#  ('Dimensional Awareness', 'Regeneration'),
#  ('Dimensional Awareness', 'Light Control'),
#  ('Dimensional Awareness', 'Echolocation'),
#  ('Dimensional Awareness', 'Levitation'),
#  ('Dimensional Awareness', 'Toxin and Disease Control'),
#  ('Dimensional Awareness', 'Banish'),
#  ('Dimensional Awareness', 'Energy Manipulation'),
#  ('Dimensional Awareness', 'Heat Resistance'),
#  ('Dimensional Awareness', 'Natural Weapons'),
#  ('Dimensional Awareness', 'Time Travel'),
#  ('Dimensional Awareness', 'Enhanced Smell'),
#  ('Dimensional Awareness', 'Illusions'),
#  ('Dimensional Awareness', 'Thirstokinesis'),
#  ('Dimensional Awareness', 'Hair Manipulation'),
#  ('Dimensional Awareness', 'Illumination'),
#  ('Dimensional Awareness', 'Omnipotent'),
#  ('Dimensional Awareness', 'Cloaking'),
#  ('Dimensional Awareness', 'Changing Armor'),
#  ('Dimensional Awareness', 'Power Cosmic'),
#  ('Dimensional Awareness', 'Biokinesis'),
#  ('Dimensional Awareness', 'Water Control'),
#  ('Dimensional Awareness', 'Radiation Immunity'),
#  ('Dimensional Awareness', 'Vision - Telescopic'),
#  ('Dimensional Awareness', 'Toxin and Disease Resistance'),
#  ('Dimensional Awareness', 'Spatial Awareness'),
#  ('Dimensional Awareness', 'Energy Resistance'),
#  ('Dimensional Awareness', 'Telepathy Resistance'),
#  ('Dimensional Awareness', 'Molecular Combustion'),
#  ('Dimensional Awareness', 'Omnilingualism'),
#  ('Dimensional Awareness', 'Portal Creation'),
#  ('Dimensional Awareness', 'Magnetism'),
#  ('Dimensional Awareness', 'Mind Control Resistance'),
#  ('Dimensional Awareness', 'Plant Control'),
#  ('Dimensional Awareness', 'Sonar'),
#  ('Dimensional Awareness', 'Sonic Scream'),
#  ('Dimensional Awareness', 'Time Manipulation'),
#  ('Dimensional Awareness', 'Enhanced Touch'),
#  ('Dimensional Awareness', 'Magic Resistance'),
#  ('Dimensional Awareness', 'Invisibility'),
#  ('Dimensional Awareness', 'Sub-Mariner'),
#  ('Dimensional Awareness', 'Radiation Absorption'),
#  ('Dimensional Awareness', 'Intuitive aptitude'),
#  ('Dimensional Awareness', 'Vision - Microscopic'),
#  ('Dimensional Awareness', 'Melting'),
#  ('Dimensional Awareness', 'Wind Control'),
#  ('Dimensional Awareness', 'Super Breath'),
#  ('Dimensional Awareness', 'Wallcrawling'),
#  ('Dimensional Awareness', 'Vision - Night'),
#  ('Dimensional Awareness', 'Vision - Infrared'),
#  ('Dimensional Awareness', 'Grim Reaping'),
#  ('Dimensional Awareness', 'Matter Absorption'),
#  ('Dimensional Awareness', 'The Force'),
#  ('Dimensional Awareness', 'Resurrection'),
#  ('Dimensional Awareness', 'Terrakinesis'),
#  ('Dimensional Awareness', 'Vision - Heat'),
#  ('Dimensional Awareness', 'Vitakinesis'),
#  ('Dimensional Awareness', 'Radar Sense'),
#  ('Dimensional Awareness', 'Qwardian Power Ring'),
#  ('Dimensional Awareness', 'Weather Control'),
#  ('Dimensional Awareness', 'Vision - X-Ray'),
#  ('Dimensional Awareness', 'Vision - Thermal'),
#  ('Dimensional Awareness', 'Web Creation'),
#  ('Dimensional Awareness', 'Reality Warping'),
#  ('Dimensional Awareness', 'Odin Force'),
#  ('Dimensional Awareness', 'Symbiote Costume'),
#  ('Dimensional Awareness', 'Speed Force'),
#  ('Dimensional Awareness', 'Phoenix Force'),
#  ('Dimensional Awareness', 'Molecular Dissipation'),
#  ('Dimensional Awareness', 'Vision - Cryo'),
#  ('Dimensional Awareness', 'Omnipresent'),
#  ('Dimensional Awareness', 'Omniscient'),
#  ('Cold Resistance', 'Agility'),
#  ('Cold Resistance', 'Accelerated Healing'),
#  ('Cold Resistance', 'Lantern Power Ring'),
#  ('Cold Resistance', 'Dimensional Awareness'),
#  ('Cold Resistance', 'Cold Resistance'),
#  ('Cold Resistance', 'Durability'),
#  ('Cold Resistance', 'Stealth'),
#  ('Cold Resistance', 'Energy Absorption'),
#  ('Cold Resistance', 'Flight'),
#  ('Cold Resistance', 'Danger Sense'),
#  ('Cold Resistance', 'Underwater breathing'),
#  ('Cold Resistance', 'Marksmanship'),
#  ('Cold Resistance', 'Weapons Master'),
#  ('Cold Resistance', 'Power Augmentation'),
#  ('Cold Resistance', 'Animal Attributes'),
#  ('Cold Resistance', 'Longevity'),
#  ('Cold Resistance', 'Intelligence'),
#  ('Cold Resistance', 'Super Strength'),
#  ('Cold Resistance', 'Cryokinesis'),
#  ('Cold Resistance', 'Telepathy'),
#  ('Cold Resistance', 'Energy Armor'),
#  ('Cold Resistance', 'Energy Blasts'),
#  ('Cold Resistance', 'Duplication'),
#  ('Cold Resistance', 'Size Changing'),
#  ('Cold Resistance', 'Density Control'),
#  ('Cold Resistance', 'Stamina'),
#  ('Cold Resistance', 'Astral Travel'),
#  ('Cold Resistance', 'Audio Control'),
#  ('Cold Resistance', 'Dexterity'),
#  ('Cold Resistance', 'Omnitrix'),
#  ('Cold Resistance', 'Super Speed'),
#  ('Cold Resistance', 'Possession'),
#  ('Cold Resistance', 'Animal Oriented Powers'),
#  ('Cold Resistance', 'Weapon-based Powers'),
#  ('Cold Resistance', 'Electrokinesis'),
#  ('Cold Resistance', 'Darkforce Manipulation'),
#  ('Cold Resistance', 'Death Touch'),
#  ('Cold Resistance', 'Teleportation'),
#  ('Cold Resistance', 'Enhanced Senses'),
#  ('Cold Resistance', 'Telekinesis'),
#  ('Cold Resistance', 'Energy Beams'),
#  ('Cold Resistance', 'Magic'),
#  ('Cold Resistance', 'Hyperkinesis'),
#  ('Cold Resistance', 'Jump'),
#  ('Cold Resistance', 'Clairvoyance'),
#  ('Cold Resistance', 'Dimensional Travel'),
#  ('Cold Resistance', 'Power Sense'),
#  ('Cold Resistance', 'Shapeshifting'),
#  ('Cold Resistance', 'Peak Human Condition'),
#  ('Cold Resistance', 'Immortality'),
#  ('Cold Resistance', 'Camouflage'),
#  ('Cold Resistance', 'Element Control'),
#  ('Cold Resistance', 'Phasing'),
#  ('Cold Resistance', 'Astral Projection'),
#  ('Cold Resistance', 'Electrical Transport'),
#  ('Cold Resistance', 'Fire Control'),
#  ('Cold Resistance', 'Projection'),
#  ('Cold Resistance', 'Summoning'),
#  ('Cold Resistance', 'Enhanced Memory'),
#  ('Cold Resistance', 'Reflexes'),
#  ('Cold Resistance', 'Invulnerability'),
#  ('Cold Resistance', 'Energy Constructs'),
#  ('Cold Resistance', 'Force Fields'),
#  ('Cold Resistance', 'Self-Sustenance'),
#  ('Cold Resistance', 'Anti-Gravity'),
#  ('Cold Resistance', 'Empathy'),
#  ('Cold Resistance', 'Power Nullifier'),
#  ('Cold Resistance', 'Radiation Control'),
#  ('Cold Resistance', 'Psionic Powers'),
#  ('Cold Resistance', 'Elasticity'),
#  ('Cold Resistance', 'Substance Secretion'),
#  ('Cold Resistance', 'Elemental Transmogrification'),
#  ('Cold Resistance', 'Technopath/Cyberpath'),
#  ('Cold Resistance', 'Photographic Reflexes'),
#  ('Cold Resistance', 'Seismic Power'),
#  ('Cold Resistance', 'Animation'),
#  ('Cold Resistance', 'Precognition'),
#  ('Cold Resistance', 'Mind Control'),
#  ('Cold Resistance', 'Fire Resistance'),
#  ('Cold Resistance', 'Power Absorption'),
#  ('Cold Resistance', 'Enhanced Hearing'),
#  ('Cold Resistance', 'Nova Force'),
#  ('Cold Resistance', 'Insanity'),
#  ('Cold Resistance', 'Hypnokinesis'),
#  ('Cold Resistance', 'Animal Control'),
#  ('Cold Resistance', 'Natural Armor'),
#  ('Cold Resistance', 'Intangibility'),
#  ('Cold Resistance', 'Enhanced Sight'),
#  ('Cold Resistance', 'Molecular Manipulation'),
#  ('Cold Resistance', 'Heat Generation'),
#  ('Cold Resistance', 'Adaptation'),
#  ('Cold Resistance', 'Gliding'),
#  ('Cold Resistance', 'Power Suit'),
#  ('Cold Resistance', 'Mind Blast'),
#  ('Cold Resistance', 'Probability Manipulation'),
#  ('Cold Resistance', 'Gravity Control'),
#  ('Cold Resistance', 'Regeneration'),
#  ('Cold Resistance', 'Light Control'),
#  ('Cold Resistance', 'Echolocation'),
#  ('Cold Resistance', 'Levitation'),
#  ('Cold Resistance', 'Toxin and Disease Control'),
#  ('Cold Resistance', 'Banish'),
#  ('Cold Resistance', 'Energy Manipulation'),
#  ('Cold Resistance', 'Heat Resistance'),
#  ('Cold Resistance', 'Natural Weapons'),
#  ('Cold Resistance', 'Time Travel'),
#  ('Cold Resistance', 'Enhanced Smell'),
#  ('Cold Resistance', 'Illusions'),
#  ('Cold Resistance', 'Thirstokinesis'),
#  ('Cold Resistance', 'Hair Manipulation'),
#  ('Cold Resistance', 'Illumination'),
#  ('Cold Resistance', 'Omnipotent'),
#  ('Cold Resistance', 'Cloaking'),
#  ('Cold Resistance', 'Changing Armor'),
#  ('Cold Resistance', 'Power Cosmic'),
#  ('Cold Resistance', 'Biokinesis'),
#  ('Cold Resistance', 'Water Control'),
#  ('Cold Resistance', 'Radiation Immunity'),
#  ('Cold Resistance', 'Vision - Telescopic'),
#  ('Cold Resistance', 'Toxin and Disease Resistance'),
#  ('Cold Resistance', 'Spatial Awareness'),
#  ('Cold Resistance', 'Energy Resistance'),
#  ('Cold Resistance', 'Telepathy Resistance'),
#  ('Cold Resistance', 'Molecular Combustion'),
#  ('Cold Resistance', 'Omnilingualism'),
#  ('Cold Resistance', 'Portal Creation'),
#  ('Cold Resistance', 'Magnetism'),
#  ('Cold Resistance', 'Mind Control Resistance'),
#  ('Cold Resistance', 'Plant Control'),
#  ('Cold Resistance', 'Sonar'),
#  ('Cold Resistance', 'Sonic Scream'),
#  ('Cold Resistance', 'Time Manipulation'),
#  ('Cold Resistance', 'Enhanced Touch'),
#  ('Cold Resistance', 'Magic Resistance'),
#  ('Cold Resistance', 'Invisibility'),
#  ('Cold Resistance', 'Sub-Mariner'),
#  ('Cold Resistance', 'Radiation Absorption'),
#  ('Cold Resistance', 'Intuitive aptitude'),
#  ('Cold Resistance', 'Vision - Microscopic'),
#  ('Cold Resistance', 'Melting'),
#  ('Cold Resistance', 'Wind Control'),
#  ('Cold Resistance', 'Super Breath'),
#  ('Cold Resistance', 'Wallcrawling'),
#  ('Cold Resistance', 'Vision - Night'),
#  ('Cold Resistance', 'Vision - Infrared'),
#  ('Cold Resistance', 'Grim Reaping'),
#  ('Cold Resistance', 'Matter Absorption'),
#  ('Cold Resistance', 'The Force'),
#  ('Cold Resistance', 'Resurrection'),
#  ('Cold Resistance', 'Terrakinesis'),
#  ('Cold Resistance', 'Vision - Heat'),
#  ('Cold Resistance', 'Vitakinesis'),
#  ('Cold Resistance', 'Radar Sense'),
#  ('Cold Resistance', 'Qwardian Power Ring'),
#  ('Cold Resistance', 'Weather Control'),
#  ('Cold Resistance', 'Vision - X-Ray'),
#  ('Cold Resistance', 'Vision - Thermal'),
#  ('Cold Resistance', 'Web Creation'),
#  ('Cold Resistance', 'Reality Warping'),
#  ('Cold Resistance', 'Odin Force'),
#  ('Cold Resistance', 'Symbiote Costume'),
#  ('Cold Resistance', 'Speed Force'),
#  ('Cold Resistance', 'Phoenix Force'),
#  ('Cold Resistance', 'Molecular Dissipation'),
#  ('Cold Resistance', 'Vision - Cryo'),
#  ('Cold Resistance', 'Omnipresent'),
#  ('Cold Resistance', 'Omniscient'),
#  ('Durability', 'Agility'),
#  ('Durability', 'Accelerated Healing'),
#  ('Durability', 'Lantern Power Ring'),
#  ('Durability', 'Dimensional Awareness'),
#  ('Durability', 'Cold Resistance'),
#  ('Durability', 'Durability'),
#  ('Durability', 'Stealth'),
#  ('Durability', 'Energy Absorption'),
#  ('Durability', 'Flight'),
#  ('Durability', 'Danger Sense'),
#  ('Durability', 'Underwater breathing'),
#  ('Durability', 'Marksmanship'),
#  ('Durability', 'Weapons Master'),
#  ('Durability', 'Power Augmentation'),
#  ('Durability', 'Animal Attributes'),
#  ('Durability', 'Longevity'),
#  ('Durability', 'Intelligence'),
#  ('Durability', 'Super Strength'),
#  ('Durability', 'Cryokinesis'),
#  ('Durability', 'Telepathy'),
#  ('Durability', 'Energy Armor'),
#  ('Durability', 'Energy Blasts'),
#  ('Durability', 'Duplication'),
#  ('Durability', 'Size Changing'),
#  ('Durability', 'Density Control'),
#  ('Durability', 'Stamina'),
#  ('Durability', 'Astral Travel'),
#  ('Durability', 'Audio Control'),
#  ('Durability', 'Dexterity'),
#  ('Durability', 'Omnitrix'),
#  ('Durability', 'Super Speed'),
#  ('Durability', 'Possession'),
#  ('Durability', 'Animal Oriented Powers'),
#  ('Durability', 'Weapon-based Powers'),
#  ('Durability', 'Electrokinesis'),
#  ('Durability', 'Darkforce Manipulation'),
#  ('Durability', 'Death Touch'),
#  ('Durability', 'Teleportation'),
#  ('Durability', 'Enhanced Senses'),
#  ('Durability', 'Telekinesis'),
#  ('Durability', 'Energy Beams'),
#  ('Durability', 'Magic'),
#  ('Durability', 'Hyperkinesis'),
#  ('Durability', 'Jump'),
#  ('Durability', 'Clairvoyance'),
#  ('Durability', 'Dimensional Travel'),
#  ('Durability', 'Power Sense'),
#  ('Durability', 'Shapeshifting'),
#  ('Durability', 'Peak Human Condition'),
#  ('Durability', 'Immortality'),
#  ('Durability', 'Camouflage'),
#  ('Durability', 'Element Control'),
#  ('Durability', 'Phasing'),
#  ('Durability', 'Astral Projection'),
#  ('Durability', 'Electrical Transport'),
#  ('Durability', 'Fire Control'),
#  ('Durability', 'Projection'),
#  ('Durability', 'Summoning'),
#  ('Durability', 'Enhanced Memory'),
#  ('Durability', 'Reflexes'),
#  ('Durability', 'Invulnerability'),
#  ('Durability', 'Energy Constructs'),
#  ('Durability', 'Force Fields'),
#  ('Durability', 'Self-Sustenance'),
#  ('Durability', 'Anti-Gravity'),
#  ('Durability', 'Empathy'),
#  ('Durability', 'Power Nullifier'),
#  ('Durability', 'Radiation Control'),
#  ('Durability', 'Psionic Powers'),
#  ('Durability', 'Elasticity'),
#  ('Durability', 'Substance Secretion'),
#  ('Durability', 'Elemental Transmogrification'),
#  ('Durability', 'Technopath/Cyberpath'),
#  ('Durability', 'Photographic Reflexes'),
#  ('Durability', 'Seismic Power'),
#  ('Durability', 'Animation'),
#  ('Durability', 'Precognition'),
#  ('Durability', 'Mind Control'),
#  ('Durability', 'Fire Resistance'),
#  ('Durability', 'Power Absorption'),
#  ('Durability', 'Enhanced Hearing'),
#  ('Durability', 'Nova Force'),
#  ('Durability', 'Insanity'),
#  ('Durability', 'Hypnokinesis'),
#  ('Durability', 'Animal Control'),
#  ('Durability', 'Natural Armor'),
#  ('Durability', 'Intangibility'),
#  ('Durability', 'Enhanced Sight'),
#  ('Durability', 'Molecular Manipulation'),
#  ('Durability', 'Heat Generation'),
#  ('Durability', 'Adaptation'),
#  ('Durability', 'Gliding'),
#  ('Durability', 'Power Suit'),
#  ('Durability', 'Mind Blast'),
#  ('Durability', 'Probability Manipulation'),
#  ('Durability', 'Gravity Control'),
#  ('Durability', 'Regeneration'),
#  ('Durability', 'Light Control'),
#  ('Durability', 'Echolocation'),
#  ('Durability', 'Levitation'),
#  ('Durability', 'Toxin and Disease Control'),
#  ('Durability', 'Banish'),
#  ('Durability', 'Energy Manipulation'),
#  ('Durability', 'Heat Resistance'),
#  ('Durability', 'Natural Weapons'),
#  ('Durability', 'Time Travel'),
#  ('Durability', 'Enhanced Smell'),
#  ('Durability', 'Illusions'),
#  ('Durability', 'Thirstokinesis'),
#  ('Durability', 'Hair Manipulation'),
#  ('Durability', 'Illumination'),
#  ('Durability', 'Omnipotent'),
#  ('Durability', 'Cloaking'),
#  ('Durability', 'Changing Armor'),
#  ('Durability', 'Power Cosmic'),
#  ('Durability', 'Biokinesis'),
#  ('Durability', 'Water Control'),
#  ('Durability', 'Radiation Immunity'),
#  ('Durability', 'Vision - Telescopic'),
#  ('Durability', 'Toxin and Disease Resistance'),
#  ('Durability', 'Spatial Awareness'),
#  ('Durability', 'Energy Resistance'),
#  ('Durability', 'Telepathy Resistance'),
#  ('Durability', 'Molecular Combustion'),
#  ('Durability', 'Omnilingualism'),
#  ('Durability', 'Portal Creation'),
#  ('Durability', 'Magnetism'),
#  ('Durability', 'Mind Control Resistance'),
#  ('Durability', 'Plant Control'),
#  ('Durability', 'Sonar'),
#  ('Durability', 'Sonic Scream'),
#  ('Durability', 'Time Manipulation'),
#  ('Durability', 'Enhanced Touch'),
#  ('Durability', 'Magic Resistance'),
#  ('Durability', 'Invisibility'),
#  ('Durability', 'Sub-Mariner'),
#  ('Durability', 'Radiation Absorption'),
#  ('Durability', 'Intuitive aptitude'),
#  ('Durability', 'Vision - Microscopic'),
#  ('Durability', 'Melting'),
#  ('Durability', 'Wind Control'),
#  ('Durability', 'Super Breath'),
#  ('Durability', 'Wallcrawling'),
#  ('Durability', 'Vision - Night'),
#  ('Durability', 'Vision - Infrared'),
#  ('Durability', 'Grim Reaping'),
#  ('Durability', 'Matter Absorption'),
#  ('Durability', 'The Force'),
#  ('Durability', 'Resurrection'),
#  ('Durability', 'Terrakinesis'),
#  ('Durability', 'Vision - Heat'),
#  ('Durability', 'Vitakinesis'),
#  ('Durability', 'Radar Sense'),
#  ('Durability', 'Qwardian Power Ring'),
#  ('Durability', 'Weather Control'),
#  ('Durability', 'Vision - X-Ray'),
#  ('Durability', 'Vision - Thermal'),
#  ('Durability', 'Web Creation'),
#  ('Durability', 'Reality Warping'),
#  ('Durability', 'Odin Force'),
#  ('Durability', 'Symbiote Costume'),
#  ('Durability', 'Speed Force'),
#  ('Durability', 'Phoenix Force'),
#  ('Durability', 'Molecular Dissipation'),
#  ('Durability', 'Vision - Cryo'),
#  ...]

# %%
# Replace None with appropriate text:
"""
None
"""

# %% [markdown]
# Some sample cells have been provided to give you room to work. Feel free to create more cells as needed.
#
# Be sure to include thoughtful, well-labeled visualizations to back up your analysis!
#
# (There is no solution branch for this part, and feel free to move on to the next lesson if you have already spent more than 90 minutes.)

# %% [markdown]
# ## Summary
#
# In this lab, you demonstrated your mastery of using pandas to clean and aggregate data in order to answer several business questions. This included identifying and handling missing values, text requiring preprocessing, and invalid values. You also performed aggregation and reshaping tasks such as transposing, joining, and grouping data. Great job, there was a lot here!
